# %%
import gym
import random
import numpy as np
from collections import deque
from keras.layers import Dense, Conv2D,Activation,Flatten
from keras.optimizers import Adam, SGD,RMSprop
from keras.models import Sequential
from skimage.util import crop
import skimage
import tensorflow as tf
from keras import utils 
import keras.backend as K
import matplotlib.pyplot as plt
import pickle
from keras.models import load_model
from keras.initializers import VarianceScaling
# Out:
# Using TensorFlow backend.
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %% [markdown]
# I used a customized loss function

# %%
def loss_mse(Y_true,Y_pred):
      global glob_act
      target= tf.keras.backend.max(Y_true,axis=1)
      new_Y_pred=K.sum((Y_pred*glob_act),axis=1)
      loss= tf.compat.v1.losses.huber_loss(labels=target,predictions=new_Y_pred,delta=1.0)
      loss_mean = tf.reduce_mean(loss)
      return (loss_mean)

# %%
actions=[0]
actions=actions*32
glob_act=utils.to_categorical(actions, num_classes=4)

# %%
class DDQNAgent:
        def __init__(self,env,path=None):
            #defining some parameters
            self.no_op_steps=30
            self.env=env
            self.path=path
            self.action_size=env.action_space.n
            self.agent_history_length=4
            self.input_img_shape=(84,84,self.agent_history_length)
            self.n_episodes=1000000
            self.max_n_steps=18000
            self.discount_factor=0.99
            self.learning_rate=0.00001
            self.epsilon=1  
            self.epsilon_decay=9.000000000000001e-07  
            self.epsilon_min=0.1
            self.batch_size=32
            self.start_train=50000
            self.n_seen_frame=1
            self.memory=deque(maxlen=1000000)
            self.reward_per_episode=[]
            self.episodic_reward=0
            self.actions=[]
            self.MAX_FRAMES = 30000000
            
            self.model=self.build_model()
            self.frozen_target_model=self.build_model()
            
            self.update_target_model()

            if (self.path!=None):
                self.model=load_model(self.path,custom_objects={'loss_mse': loss_mse})
                self.frozen_target_model=load_model(self.path, custom_objects={'loss_mse': loss_mse})

        
 
        def build_model(self):
            #building the NN model
            model=Sequential()
            model.add(Conv2D(16, (8, 8), strides=(4, 4), input_shape=self.input_img_shape,kernel_initializer=VarianceScaling(scale=2))) 
            model.add(Activation('relu')) 
            model.add(Conv2D(32, (4, 4), strides=(2, 2),kernel_initializer=VarianceScaling(scale=2)))
            model.add(Activation('relu'))  
            model.add(Flatten()) 
            model.add(Dense(256,activation="relu",kernel_initializer=VarianceScaling(scale=2))) 
            model.add(Dense(self.action_size,activation="linear",kernel_initializer=VarianceScaling(scale=2)))
            model.compile(loss=loss_mse,optimizer=RMSprop(lr=0.00025, rho=0.95, epsilon=0.01))
            model.summary()
            return model
        def update_target_model(self):
            #function to update the target model every few steps
            self.frozen_target_model.set_weights(self.model.get_weights())
        
        def reset(self):
          #function that prepares the initial state in every episode
          frame = self.env.reset() 
          for _ in range(random.randint(1, self.no_op_steps)):
              frame, _, _, _ = self.env.step(1) # Action 'Fire'
          return (frame)


        def eps_greedy_policy(self,state):
            # this is the epsilon-greedy policy, the algorithm tries to find the optimal policy 
            # by following this policy
            state_stacked=np.expand_dims(state,axis=0)
            if (self.n_seen_frame<50000):
              self.epsilon=1
            elif (self.epsilon<self.epsilon_min):
                self.epsilon=self.epsilon_min
            else:
                self.epsilon=self.epsilon-self.epsilon_decay
            if (np.random.rand()<=self.epsilon):
                return (random.randint(0,self.action_size-1))
            else :
                state_stacked= state_stacked/255.0      
                state_stacked=state_stacked.astype('float32')
                q_value=self.model.predict(state_stacked)
                return (np.argmax(q_value[0]))
        def greedy_policy(self,state):
            # this is the greedy-policy, the policy which the algorithm tries to optimize
            state_stacked=np.expand_dims(state,axis=0)
            state_stacked= state_stacked/255.0      
            state_stacked=state_stacked.astype('float32')
            q_value=self.model.predict(state_stacked)
            return (np.argmax(q_value[0]))
        
        def memorize_sample(self,state,action,reward,done):
                # function that will append a sample to the memory.
                
                reward=self.clip_reward(reward)
                self.memory.append((state,action,reward,done))
        def clip_reward(self,reward):
            #function to clip the reward
          if (reward>0):
            r=1
          elif(reward==0):
            r=0
          else:
            r=-1
          return(r)
        def preprocess_input(self,img):
            # Function to preprocess the input
            # convert the input from rgb to grey 
            image = skimage.color.rgb2gray(img)
            # resize image to 80x80 from 288x404 
            image = skimage.transform.resize(image,(110,84), mode='constant') 
            # return image after stretching/shrinking its intensity levels 
            #image = skimage.exposure.rescale_intensity(image,out_range=(0,255)) 
            image=image[17:101,0:84]
            image=(image*256).astype('uint8')
            # scale down pixels values to (0,1) 
            #image = image / 255.0 
            #image=image.astype('float32')
            return image
        def get_mini_batch(self):
                #function that sample a mini-batch from the memory to use it for training.
                first_state=np.empty((self.batch_size,self.input_img_shape[0],self.input_img_shape[1],self.agent_history_length))
                next_state=np.empty((self.batch_size,self.input_img_shape[0],self.input_img_shape[1],self.agent_history_length))
                actions,reward,done=[],[],[]
                for i in range(self.batch_size):
                  while True:
                    index = random.randint(self.agent_history_length-1, len(self.memory)-2)
                    if ((self.memory[index][3]!=True) & (self.memory[index-1][3]!=True) & (self.memory[index-2][3]!=True) & (self.memory[index-3][3]!=True)):
                      break
                  stacked_first_state=np.stack([self.memory[index-3][0],self.memory[index-2][0],self.memory[index-1][0],self.memory[index][0]],axis=2)
                  stacked_next_state=np.stack([self.memory[index-2][0],self.memory[index-1][0],self.memory[index][0],self.memory[index+1][0]],axis=2)
                  first_state[i]=stacked_first_state
                  next_state[i]=stacked_next_state
                  actions.append(self.memory[index][1])
                  reward.append(self.memory[index][2])
                  done.append(self.memory[index][3])
                return(first_state,actions,reward,next_state,done)



        
        def train_model(self):
            # This function uses all of the above to train the model.
            # It is also reponsible for saving the models and the needed paramters to resume the training.
            for episode in range(self.n_episodes):
              if(self.n_seen_frame>self.MAX_FRAMES):
                break
              resting_lives=5
              if (episode%300==0):
                model_save_name = '11_Huber_target_model_'+str(episode)
                path = F"/content/gdrive/My Drive/DDQN_Breakout_V4/{model_save_name}.h5" 
                agent.frozen_target_model.save(path)
                mylist=[]
                mylist.append(self.reward_per_episode)
                mylist.append(episode)
                mylist.append(self.epsilon)
                list_name="11_Huber_reward_episode_epsilon_"+str(episode)
                with open(F"/content/gdrive/My Drive/DDQN_Breakout_V4/{list_name}.pkl", "wb") as fp:
                  pickle.dump(mylist, fp)
                memory_name="11_Huber_memory_"+str(episode)
                with open(F"/content/gdrive/My Drive/DDQN_Breakout_V4/{memory_name}.pkl", "wb") as fp:
                  pickle.dump(self.memory, fp)
                n_seen_frames="11_Huber_n_seen_frames"+str(episode)
                with open(F"/content/gdrive/My Drive/DDQN_Breakout_V4/{n_seen_frames}.pkl", "wb") as fp:
                  pickle.dump(self.n_seen_frame, fp)
              global glob_act
              print("episode {}/{}".format(episode,self.n_episodes))
              print("number of seen frames = {}".format(self.n_seen_frame))
              print("epsilon = {}".format(self.epsilon))
              
              self.reward_per_episode.append(self.episodic_reward)
              print("average reward in episode {} = {}".format(episode,self.reward_per_episode[-1]))
              print("\n")
              self.episodic_reward=0

              state=self.reset()
              processed_state=self.preprocess_input(state)
              stacked_processed_state=np.stack([processed_state for i in range(self.agent_history_length)],axis=2)
              done=False
              for step in range(self.max_n_steps):
                if (done==True):
                  print("done at step {}".format(step))
                  break
                
                
                
                
                
                action=self.eps_greedy_policy(stacked_processed_state)
                next_state,reward,done,info=self.env.step(action)

                self.episodic_reward+=reward
                self.memorize_sample(processed_state,action,reward,done)
                state=next_state
                processed_state=self.preprocess_input(state)
                stacked_processed_state[:,:,0:self.agent_history_length-1]=stacked_processed_state[:,:,1:self.agent_history_length]
                stacked_processed_state[:,:,self.agent_history_length-1]=processed_state
                self.n_seen_frame+=1
                


                
                if len(self.memory)< self.start_train:
                  continue
                
                if (self.n_seen_frame%4==0):
                  first_states,self.actions,rewards,next_states,dones=self.get_mini_batch()
                  next_states=next_states/255.0
                  next_states=next_states.astype('float32')
                  q_target=self.frozen_target_model.predict(next_states)
                  for i in range(len(dones)):
                    if (dones[i]==True):
                      ((q_target == (q_target.max(axis=1)[:,None]))*rewards[i])[i,:]
                    else:
                      q_target[i,:]=self.discount_factor*q_target[i,:]+rewards[i]
                  #print(q_target)
                  #print(q_target.shape)
                  
                  glob_act=utils.to_categorical(self.actions, num_classes=self.action_size)
                  
                  first_states=next_states/255.0
                  first_states=next_states.astype('float32')
                  self.model.fit(x=first_states,y=q_target,batch_size=self.batch_size,epochs=1,verbose=0)
                  if (self.n_seen_frame%10000==0):
                    self.update_target_model()

# %%
#defining the environment and the agent
env=gym.make("BreakoutDeterministic-v4")
agent=DDQNAgent(env=env)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4479: The name tf.truncated_normal is deprecated. Please use tf.random.truncated_normal instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/losses/losses_impl.py:121: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 20, 20, 16)        4112
# _________________________________________________________________
# activation_1 (Activation)    (None, 20, 20, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 9, 9, 32)          8224
# _________________________________________________________________
# activation_2 (Activation)    (None, 9, 9, 32)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2592)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               663808
# _________________________________________________________________
# dense_2 (Dense)              (None, 4)                 1028
# =================================================================
# Total params: 677,172
# Trainable params: 677,172
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_3 (Conv2D)            (None, 20, 20, 16)        4112
# _________________________________________________________________
# activation_3 (Activation)    (None, 20, 20, 16)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 9, 9, 32)          8224
# _________________________________________________________________
# activation_4 (Activation)    (None, 9, 9, 32)          0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 2592)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 256)               663808
# _________________________________________________________________
# dense_4 (Dense)              (None, 4)                 1028
# =================================================================
# Total params: 677,172
# Trainable params: 677,172
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:203: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.

# %%
# First time we started the training.
agent.train_model()
# Out:
# episode 0/1000000
# number of seen frames = 1
# epsilon = 1
# average reward in episode 0 = 0
# done at step 169
# episode 1/1000000
# number of seen frames = 170
# epsilon = 1
# average reward in episode 1 = 2.0
# done at step 157
# episode 2/1000000
# number of seen frames = 327
# epsilon = 1
# average reward in episode 2 = 1.0
# done at step 189
# episode 3/1000000
# number of seen frames = 516
# epsilon = 1
# average reward in episode 3 = 2.0
# done at step 156
# episode 4/1000000
# number of seen frames = 672
# epsilon = 1
# average reward in episode 4 = 1.0
# done at step 161
# episode 5/1000000
# number of seen frames = 833
# epsilon = 1
# average reward in episode 5 = 1.0
# done at step 239
# episode 6/1000000
# number of seen frames = 1072
# epsilon = 1
# average reward in episode 6 = 3.0
# done at step 115
# episode 7/1000000
# number of seen frames = 1187
# epsilon = 1
# average reward in episode 7 = 0.0
# done at step 147
# episode 8/1000000
# number of seen frames = 1334
# epsilon = 1
# average reward in episode 8 = 1.0
# done at step 128
# episode 9/1000000
# number of seen frames = 1462
# epsilon = 1
# average reward in episode 9 = 0.0
# done at step 97
# episode 10/1000000
# number of seen frames = 1559
# epsilon = 1
# average reward in episode 10 = 0.0
# done at step 104
# episode 11/1000000
# number of seen frames = 1663
# epsilon = 1
# average reward in episode 11 = 0.0
# done at step 105
# episode 12/1000000
# number of seen frames = 1768
# epsilon = 1
# average reward in episode 12 = 0.0
# done at step 205
# episode 13/1000000
# number of seen frames = 1973
# epsilon = 1
# average reward in episode 13 = 2.0
# done at step 127
# episode 14/1000000
# number of seen frames = 2100
# epsilon = 1
# average reward in episode 14 = 0.0
# done at step 150
# episode 15/1000000
# number of seen frames = 2250
# epsilon = 1
# average reward in episode 15 = 1.0
# done at step 106
# episode 16/1000000
# number of seen frames = 2356
# epsilon = 1
# average reward in episode 16 = 0.0
# done at step 131
# episode 17/1000000
# number of seen frames = 2487
# epsilon = 1
# average reward in episode 17 = 1.0
# done at step 204
# episode 18/1000000
# number of seen frames = 2691
# epsilon = 1
# average reward in episode 18 = 2.0
# done at step 170
# episode 19/1000000
# number of seen frames = 2861
# epsilon = 1
# average reward in episode 19 = 2.0
# done at step 159
# episode 20/1000000
# number of seen frames = 3020
# epsilon = 1
# average reward in episode 20 = 1.0
# done at step 124
# episode 21/1000000
# number of seen frames = 3144
# epsilon = 1
# average reward in episode 21 = 0.0
# done at step 254
# episode 22/1000000
# number of seen frames = 3398
# epsilon = 1
# average reward in episode 22 = 3.0
# done at step 177
# episode 23/1000000
# number of seen frames = 3575
# epsilon = 1
# average reward in episode 23 = 2.0
# done at step 129
# episode 24/1000000
# number of seen frames = 3704
# epsilon = 1
# average reward in episode 24 = 0.0
# done at step 119
# episode 25/1000000
# number of seen frames = 3823
# epsilon = 1
# average reward in episode 25 = 0.0
# done at step 160
# episode 26/1000000
# number of seen frames = 3983
# epsilon = 1
# average reward in episode 26 = 1.0
# done at step 135
# episode 27/1000000
# number of seen frames = 4118
# epsilon = 1
# average reward in episode 27 = 0.0
# done at step 164
# episode 28/1000000
# number of seen frames = 4282
# epsilon = 1
# average reward in episode 28 = 1.0
# done at step 133
# episode 29/1000000
# number of seen frames = 4415
# epsilon = 1
# average reward in episode 29 = 0.0
# done at step 103
# episode 30/1000000
# number of seen frames = 4518
# epsilon = 1
# average reward in episode 30 = 0.0
# done at step 137
# episode 31/1000000
# number of seen frames = 4655
# epsilon = 1
# average reward in episode 31 = 1.0
# done at step 107
# episode 32/1000000
# number of seen frames = 4762
# epsilon = 1
# average reward in episode 32 = 0.0
# done at step 122
# episode 33/1000000
# number of seen frames = 4884
# epsilon = 1
# average reward in episode 33 = 0.0
# done at step 158
# episode 34/1000000
# number of seen frames = 5042
# epsilon = 1
# average reward in episode 34 = 1.0
# done at step 206
# episode 35/1000000
# number of seen frames = 5248
# epsilon = 1
# average reward in episode 35 = 2.0
# done at step 185
# episode 36/1000000
# number of seen frames = 5433
# epsilon = 1
# average reward in episode 36 = 2.0
# done at step 218
# episode 37/1000000
# number of seen frames = 5651
# epsilon = 1
# average reward in episode 37 = 2.0
# done at step 185
# episode 38/1000000
# number of seen frames = 5836
# epsilon = 1
# average reward in episode 38 = 2.0
# done at step 123
# episode 39/1000000
# number of seen frames = 5959
# epsilon = 1
# average reward in episode 39 = 0.0
# done at step 112
# episode 40/1000000
# number of seen frames = 6071
# epsilon = 1
# average reward in episode 40 = 0.0
# done at step 133
# episode 41/1000000
# number of seen frames = 6204
# epsilon = 1
# average reward in episode 41 = 0.0
# done at step 137
# episode 42/1000000
# number of seen frames = 6341
# epsilon = 1
# average reward in episode 42 = 1.0
# done at step 122
# episode 43/1000000
# number of seen frames = 6463
# epsilon = 1
# average reward in episode 43 = 0.0
# done at step 117
# episode 44/1000000
# number of seen frames = 6580
# epsilon = 1
# average reward in episode 44 = 0.0
# done at step 119
# episode 45/1000000
# number of seen frames = 6699
# epsilon = 1
# average reward in episode 45 = 0.0
# done at step 157
# episode 46/1000000
# number of seen frames = 6856
# epsilon = 1
# average reward in episode 46 = 1.0
# done at step 169
# episode 47/1000000
# number of seen frames = 7025
# epsilon = 1
# average reward in episode 47 = 1.0
# done at step 154
# episode 48/1000000
# number of seen frames = 7179
# epsilon = 1
# average reward in episode 48 = 1.0
# done at step 168
# episode 49/1000000
# number of seen frames = 7347
# epsilon = 1
# average reward in episode 49 = 1.0
# done at step 280
# episode 50/1000000
# number of seen frames = 7627
# epsilon = 1
# average reward in episode 50 = 4.0
# done at step 104
# episode 51/1000000
# number of seen frames = 7731
# epsilon = 1
# average reward in episode 51 = 0.0
# done at step 136
# episode 52/1000000
# number of seen frames = 7867
# epsilon = 1
# average reward in episode 52 = 0.0
# done at step 112
# episode 53/1000000
# number of seen frames = 7979
# epsilon = 1
# average reward in episode 53 = 0.0
# done at step 195
# episode 54/1000000
# number of seen frames = 8174
# epsilon = 1
# average reward in episode 54 = 2.0
# done at step 128
# episode 55/1000000
# number of seen frames = 8302
# epsilon = 1
# average reward in episode 55 = 0.0
# done at step 103
# episode 56/1000000
# number of seen frames = 8405
# epsilon = 1
# average reward in episode 56 = 0.0
# done at step 128
# episode 57/1000000
# number of seen frames = 8533
# epsilon = 1
# average reward in episode 57 = 0.0
# done at step 215
# episode 58/1000000
# number of seen frames = 8748
# epsilon = 1
# average reward in episode 58 = 2.0
# done at step 172
# episode 59/1000000
# number of seen frames = 8920
# epsilon = 1
# average reward in episode 59 = 1.0
# done at step 171
# episode 60/1000000
# number of seen frames = 9091
# epsilon = 1
# average reward in episode 60 = 1.0
# done at step 145
# episode 61/1000000
# number of seen frames = 9236
# epsilon = 1
# average reward in episode 61 = 1.0
# done at step 231
# episode 62/1000000
# number of seen frames = 9467
# epsilon = 1
# average reward in episode 62 = 3.0
# done at step 129
# episode 63/1000000
# number of seen frames = 9596
# epsilon = 1
# average reward in episode 63 = 0.0
# done at step 112
# episode 64/1000000
# number of seen frames = 9708
# epsilon = 1
# average reward in episode 64 = 0.0
# done at step 234
# episode 65/1000000
# number of seen frames = 9942
# epsilon = 1
# average reward in episode 65 = 4.0
# done at step 117
# episode 66/1000000
# number of seen frames = 10059
# epsilon = 1
# average reward in episode 66 = 0.0
# done at step 184
# episode 67/1000000
# number of seen frames = 10243
# epsilon = 1
# average reward in episode 67 = 2.0
# done at step 115
# episode 68/1000000
# number of seen frames = 10358
# epsilon = 1
# average reward in episode 68 = 0.0
# done at step 215
# episode 69/1000000
# number of seen frames = 10573
# epsilon = 1
# average reward in episode 69 = 2.0
# done at step 172
# episode 70/1000000
# number of seen frames = 10745
# epsilon = 1
# average reward in episode 70 = 2.0
# done at step 127
# episode 71/1000000
# number of seen frames = 10872
# epsilon = 1
# average reward in episode 71 = 0.0
# done at step 109
# episode 72/1000000
# number of seen frames = 10981
# epsilon = 1
# average reward in episode 72 = 0.0
# done at step 118
# episode 73/1000000
# number of seen frames = 11099
# epsilon = 1
# average reward in episode 73 = 0.0
# done at step 138
# episode 74/1000000
# number of seen frames = 11237
# epsilon = 1
# average reward in episode 74 = 0.0
# done at step 186
# episode 75/1000000
# number of seen frames = 11423
# epsilon = 1
# average reward in episode 75 = 2.0
# done at step 116
# episode 76/1000000
# number of seen frames = 11539
# epsilon = 1
# average reward in episode 76 = 0.0
# done at step 147
# episode 77/1000000
# number of seen frames = 11686
# epsilon = 1
# average reward in episode 77 = 1.0
# done at step 148
# episode 78/1000000
# number of seen frames = 11834
# epsilon = 1
# average reward in episode 78 = 1.0
# done at step 162
# episode 79/1000000
# number of seen frames = 11996
# epsilon = 1
# average reward in episode 79 = 1.0
# done at step 188
# episode 80/1000000
# number of seen frames = 12184
# epsilon = 1
# average reward in episode 80 = 1.0
# done at step 204
# episode 81/1000000
# number of seen frames = 12388
# epsilon = 1
# average reward in episode 81 = 2.0
# done at step 134
# episode 82/1000000
# number of seen frames = 12522
# epsilon = 1
# average reward in episode 82 = 0.0
# done at step 140
# episode 83/1000000
# number of seen frames = 12662
# epsilon = 1
# average reward in episode 83 = 0.0
# done at step 139
# episode 84/1000000
# number of seen frames = 12801
# epsilon = 1
# average reward in episode 84 = 1.0
# done at step 165
# episode 85/1000000
# number of seen frames = 12966
# epsilon = 1
# average reward in episode 85 = 1.0
# done at step 206
# episode 86/1000000
# number of seen frames = 13172
# epsilon = 1
# average reward in episode 86 = 3.0
# done at step 156
# episode 87/1000000
# number of seen frames = 13328
# epsilon = 1
# average reward in episode 87 = 1.0
# done at step 97
# episode 88/1000000
# number of seen frames = 13425
# epsilon = 1
# average reward in episode 88 = 0.0
# done at step 115
# episode 89/1000000
# number of seen frames = 13540
# epsilon = 1
# average reward in episode 89 = 0.0
# done at step 106
# episode 90/1000000
# number of seen frames = 13646
# epsilon = 1
# average reward in episode 90 = 0.0
# done at step 247
# episode 91/1000000
# number of seen frames = 13893
# epsilon = 1
# average reward in episode 91 = 4.0
# done at step 111
# episode 92/1000000
# number of seen frames = 14004
# epsilon = 1
# average reward in episode 92 = 0.0
# done at step 139
# episode 93/1000000
# number of seen frames = 14143
# epsilon = 1
# average reward in episode 93 = 1.0
# done at step 117
# episode 94/1000000
# number of seen frames = 14260
# epsilon = 1
# average reward in episode 94 = 0.0
# done at step 174
# episode 95/1000000
# number of seen frames = 14434
# epsilon = 1
# average reward in episode 95 = 1.0
# done at step 176
# episode 96/1000000
# number of seen frames = 14610
# epsilon = 1
# average reward in episode 96 = 2.0
# done at step 110
# episode 97/1000000
# number of seen frames = 14720
# epsilon = 1
# average reward in episode 97 = 0.0
# done at step 178
# episode 98/1000000
# number of seen frames = 14898
# epsilon = 1
# average reward in episode 98 = 2.0
# done at step 187
# episode 99/1000000
# number of seen frames = 15085
# epsilon = 1
# average reward in episode 99 = 2.0
# done at step 177
# episode 100/1000000
# number of seen frames = 15262
# epsilon = 1
# average reward in episode 100 = 1.0
# done at step 187
# episode 101/1000000
# number of seen frames = 15449
# epsilon = 1
# average reward in episode 101 = 2.0
# done at step 110
# episode 102/1000000
# number of seen frames = 15559
# epsilon = 1
# average reward in episode 102 = 0.0
# done at step 129
# episode 103/1000000
# number of seen frames = 15688
# epsilon = 1
# average reward in episode 103 = 0.0
# done at step 183
# episode 104/1000000
# number of seen frames = 15871
# epsilon = 1
# average reward in episode 104 = 2.0
# done at step 196
# episode 105/1000000
# number of seen frames = 16067
# epsilon = 1
# average reward in episode 105 = 2.0
# done at step 219
# episode 106/1000000
# number of seen frames = 16286
# epsilon = 1
# average reward in episode 106 = 3.0
# done at step 211
# episode 107/1000000
# number of seen frames = 16497
# epsilon = 1
# average reward in episode 107 = 3.0
# done at step 121
# episode 108/1000000
# number of seen frames = 16618
# epsilon = 1
# average reward in episode 108 = 0.0
# done at step 114
# episode 109/1000000
# number of seen frames = 16732
# epsilon = 1
# average reward in episode 109 = 0.0
# done at step 164
# episode 110/1000000
# number of seen frames = 16896
# epsilon = 1
# average reward in episode 110 = 1.0
# done at step 202
# episode 111/1000000
# number of seen frames = 17098
# epsilon = 1
# average reward in episode 111 = 3.0
# done at step 109
# episode 112/1000000
# number of seen frames = 17207
# epsilon = 1
# average reward in episode 112 = 0.0
# done at step 126
# episode 113/1000000
# number of seen frames = 17333
# epsilon = 1
# average reward in episode 113 = 0.0
# done at step 125
# episode 114/1000000
# number of seen frames = 17458
# epsilon = 1
# average reward in episode 114 = 0.0
# done at step 153
# episode 115/1000000
# number of seen frames = 17611
# epsilon = 1
# average reward in episode 115 = 1.0
# done at step 127
# episode 116/1000000
# number of seen frames = 17738
# epsilon = 1
# average reward in episode 116 = 0.0
# done at step 160
# episode 117/1000000
# number of seen frames = 17898
# epsilon = 1
# average reward in episode 117 = 1.0
# done at step 185
# episode 118/1000000
# number of seen frames = 18083
# epsilon = 1
# average reward in episode 118 = 2.0
# done at step 125
# episode 119/1000000
# number of seen frames = 18208
# epsilon = 1
# average reward in episode 119 = 0.0
# done at step 191
# episode 120/1000000
# number of seen frames = 18399
# epsilon = 1
# average reward in episode 120 = 2.0
# done at step 197
# episode 121/1000000
# number of seen frames = 18596
# epsilon = 1
# average reward in episode 121 = 3.0
# done at step 160
# episode 122/1000000
# number of seen frames = 18756
# epsilon = 1
# average reward in episode 122 = 2.0
# done at step 201
# episode 123/1000000
# number of seen frames = 18957
# epsilon = 1
# average reward in episode 123 = 2.0
# done at step 106
# episode 124/1000000
# number of seen frames = 19063
# epsilon = 1
# average reward in episode 124 = 0.0
# done at step 178
# episode 125/1000000
# number of seen frames = 19241
# epsilon = 1
# average reward in episode 125 = 1.0
# done at step 166
# episode 126/1000000
# number of seen frames = 19407
# epsilon = 1
# average reward in episode 126 = 1.0
# done at step 107
# episode 127/1000000
# number of seen frames = 19514
# epsilon = 1
# average reward in episode 127 = 0.0
# done at step 168
# episode 128/1000000
# number of seen frames = 19682
# epsilon = 1
# average reward in episode 128 = 1.0
# done at step 120
# episode 129/1000000
# number of seen frames = 19802
# epsilon = 1
# average reward in episode 129 = 0.0
# done at step 129
# episode 130/1000000
# number of seen frames = 19931
# epsilon = 1
# average reward in episode 130 = 0.0
# done at step 116
# episode 131/1000000
# number of seen frames = 20047
# epsilon = 1
# average reward in episode 131 = 0.0
# done at step 174
# episode 132/1000000
# number of seen frames = 20221
# epsilon = 1
# average reward in episode 132 = 2.0
# done at step 118
# episode 133/1000000
# number of seen frames = 20339
# epsilon = 1
# average reward in episode 133 = 0.0
# done at step 168
# episode 134/1000000
# number of seen frames = 20507
# epsilon = 1
# average reward in episode 134 = 1.0
# done at step 109
# episode 135/1000000
# number of seen frames = 20616
# epsilon = 1
# average reward in episode 135 = 0.0
# done at step 118
# episode 136/1000000
# number of seen frames = 20734
# epsilon = 1
# average reward in episode 136 = 0.0
# done at step 171
# episode 137/1000000
# number of seen frames = 20905
# epsilon = 1
# average reward in episode 137 = 2.0
# done at step 180
# episode 138/1000000
# number of seen frames = 21085
# epsilon = 1
# average reward in episode 138 = 2.0
# done at step 218
# episode 139/1000000
# number of seen frames = 21303
# epsilon = 1
# average reward in episode 139 = 3.0
# done at step 110
# episode 140/1000000
# number of seen frames = 21413
# epsilon = 1
# average reward in episode 140 = 0.0
# done at step 160
# episode 141/1000000
# number of seen frames = 21573
# epsilon = 1
# average reward in episode 141 = 1.0
# done at step 117
# episode 142/1000000
# number of seen frames = 21690
# epsilon = 1
# average reward in episode 142 = 0.0
# done at step 117
# episode 143/1000000
# number of seen frames = 21807
# epsilon = 1
# average reward in episode 143 = 0.0
# done at step 99
# episode 144/1000000
# number of seen frames = 21906
# epsilon = 1
# average reward in episode 144 = 0.0
# done at step 124
# episode 145/1000000
# number of seen frames = 22030
# epsilon = 1
# average reward in episode 145 = 0.0
# done at step 126
# episode 146/1000000
# number of seen frames = 22156
# epsilon = 1
# average reward in episode 146 = 0.0
# done at step 104
# episode 147/1000000
# number of seen frames = 22260
# epsilon = 1
# average reward in episode 147 = 0.0
# done at step 185
# episode 148/1000000
# number of seen frames = 22445
# epsilon = 1
# average reward in episode 148 = 2.0
# done at step 238
# episode 149/1000000
# number of seen frames = 22683
# epsilon = 1
# average reward in episode 149 = 3.0
# done at step 128
# episode 150/1000000
# number of seen frames = 22811
# epsilon = 1
# average reward in episode 150 = 0.0
# done at step 153
# episode 151/1000000
# number of seen frames = 22964
# epsilon = 1
# average reward in episode 151 = 1.0
# done at step 185
# episode 152/1000000
# number of seen frames = 23149
# epsilon = 1
# average reward in episode 152 = 2.0
# done at step 109
# episode 153/1000000
# number of seen frames = 23258
# epsilon = 1
# average reward in episode 153 = 0.0
# done at step 201
# episode 154/1000000
# number of seen frames = 23459
# epsilon = 1
# average reward in episode 154 = 2.0
# done at step 131
# episode 155/1000000
# number of seen frames = 23590
# epsilon = 1
# average reward in episode 155 = 0.0
# done at step 135
# episode 156/1000000
# number of seen frames = 23725
# epsilon = 1
# average reward in episode 156 = 1.0
# done at step 185
# episode 157/1000000
# number of seen frames = 23910
# epsilon = 1
# average reward in episode 157 = 2.0
# done at step 125
# episode 158/1000000
# number of seen frames = 24035
# epsilon = 1
# average reward in episode 158 = 0.0
# done at step 163
# episode 159/1000000
# number of seen frames = 24198
# epsilon = 1
# average reward in episode 159 = 1.0
# done at step 131
# episode 160/1000000
# number of seen frames = 24329
# epsilon = 1
# average reward in episode 160 = 0.0
# done at step 143
# episode 161/1000000
# number of seen frames = 24472
# epsilon = 1
# average reward in episode 161 = 1.0
# done at step 120
# episode 162/1000000
# number of seen frames = 24592
# epsilon = 1
# average reward in episode 162 = 0.0
# done at step 212
# episode 163/1000000
# number of seen frames = 24804
# epsilon = 1
# average reward in episode 163 = 3.0
# done at step 130
# episode 164/1000000
# number of seen frames = 24934
# epsilon = 1
# average reward in episode 164 = 1.0
# done at step 154
# episode 165/1000000
# number of seen frames = 25088
# epsilon = 1
# average reward in episode 165 = 1.0
# done at step 107
# episode 166/1000000
# number of seen frames = 25195
# epsilon = 1
# average reward in episode 166 = 0.0
# done at step 127
# episode 167/1000000
# number of seen frames = 25322
# epsilon = 1
# average reward in episode 167 = 1.0
# done at step 136
# episode 168/1000000
# number of seen frames = 25458
# epsilon = 1
# average reward in episode 168 = 0.0
# done at step 139
# episode 169/1000000
# number of seen frames = 25597
# epsilon = 1
# average reward in episode 169 = 0.0
# done at step 207
# episode 170/1000000
# number of seen frames = 25804
# epsilon = 1
# average reward in episode 170 = 2.0
# done at step 133
# episode 171/1000000
# number of seen frames = 25937
# epsilon = 1
# average reward in episode 171 = 1.0
# done at step 163
# episode 172/1000000
# number of seen frames = 26100
# epsilon = 1
# average reward in episode 172 = 1.0
# done at step 122
# episode 173/1000000
# number of seen frames = 26222
# epsilon = 1
# average reward in episode 173 = 0.0
# done at step 145
# episode 174/1000000
# number of seen frames = 26367
# epsilon = 1
# average reward in episode 174 = 1.0
# done at step 105
# episode 175/1000000
# number of seen frames = 26472
# epsilon = 1
# average reward in episode 175 = 0.0
# done at step 146
# episode 176/1000000
# number of seen frames = 26618
# epsilon = 1
# average reward in episode 176 = 1.0
# done at step 179
# episode 177/1000000
# number of seen frames = 26797
# epsilon = 1
# average reward in episode 177 = 1.0
# done at step 117
# episode 178/1000000
# number of seen frames = 26914
# epsilon = 1
# average reward in episode 178 = 0.0
# done at step 197
# episode 179/1000000
# number of seen frames = 27111
# epsilon = 1
# average reward in episode 179 = 2.0
# done at step 138
# episode 180/1000000
# number of seen frames = 27249
# epsilon = 1
# average reward in episode 180 = 1.0
# done at step 111
# episode 181/1000000
# number of seen frames = 27360
# epsilon = 1
# average reward in episode 181 = 0.0
# done at step 180
# episode 182/1000000
# number of seen frames = 27540
# epsilon = 1
# average reward in episode 182 = 2.0
# done at step 127
# episode 183/1000000
# number of seen frames = 27667
# epsilon = 1
# average reward in episode 183 = 0.0
# done at step 240
# episode 184/1000000
# number of seen frames = 27907
# epsilon = 1
# average reward in episode 184 = 3.0
# done at step 197
# episode 185/1000000
# number of seen frames = 28104
# epsilon = 1
# average reward in episode 185 = 3.0
# done at step 114
# episode 186/1000000
# number of seen frames = 28218
# epsilon = 1
# average reward in episode 186 = 0.0
# done at step 117
# episode 187/1000000
# number of seen frames = 28335
# epsilon = 1
# average reward in episode 187 = 0.0
# done at step 113
# episode 188/1000000
# number of seen frames = 28448
# epsilon = 1
# average reward in episode 188 = 0.0
# done at step 125
# episode 189/1000000
# number of seen frames = 28573
# epsilon = 1
# average reward in episode 189 = 0.0
# done at step 161
# episode 190/1000000
# number of seen frames = 28734
# epsilon = 1
# average reward in episode 190 = 1.0
# done at step 195
# episode 191/1000000
# number of seen frames = 28929
# epsilon = 1
# average reward in episode 191 = 2.0
# done at step 173
# episode 192/1000000
# number of seen frames = 29102
# epsilon = 1
# average reward in episode 192 = 1.0
# done at step 224
# episode 193/1000000
# number of seen frames = 29326
# epsilon = 1
# average reward in episode 193 = 2.0
# done at step 204
# episode 194/1000000
# number of seen frames = 29530
# epsilon = 1
# average reward in episode 194 = 2.0
# done at step 125
# episode 195/1000000
# number of seen frames = 29655
# epsilon = 1
# average reward in episode 195 = 0.0
# done at step 148
# episode 196/1000000
# number of seen frames = 29803
# epsilon = 1
# average reward in episode 196 = 1.0
# done at step 123
# episode 197/1000000
# number of seen frames = 29926
# epsilon = 1
# average reward in episode 197 = 0.0
# done at step 124
# episode 198/1000000
# number of seen frames = 30050
# epsilon = 1
# average reward in episode 198 = 0.0
# done at step 180
# episode 199/1000000
# number of seen frames = 30230
# epsilon = 1
# average reward in episode 199 = 2.0
# done at step 191
# episode 200/1000000
# number of seen frames = 30421
# epsilon = 1
# average reward in episode 200 = 2.0
# done at step 136
# episode 201/1000000
# number of seen frames = 30557
# epsilon = 1
# average reward in episode 201 = 0.0
# done at step 118
# episode 202/1000000
# number of seen frames = 30675
# epsilon = 1
# average reward in episode 202 = 0.0
# done at step 142
# episode 203/1000000
# number of seen frames = 30817
# epsilon = 1
# average reward in episode 203 = 1.0
# done at step 187
# episode 204/1000000
# number of seen frames = 31004
# epsilon = 1
# average reward in episode 204 = 2.0
# done at step 172
# episode 205/1000000
# number of seen frames = 31176
# epsilon = 1
# average reward in episode 205 = 1.0
# done at step 120
# episode 206/1000000
# number of seen frames = 31296
# epsilon = 1
# average reward in episode 206 = 0.0
# done at step 163
# episode 207/1000000
# number of seen frames = 31459
# epsilon = 1
# average reward in episode 207 = 1.0
# done at step 171
# episode 208/1000000
# number of seen frames = 31630
# epsilon = 1
# average reward in episode 208 = 1.0
# done at step 193
# episode 209/1000000
# number of seen frames = 31823
# epsilon = 1
# average reward in episode 209 = 2.0
# done at step 110
# episode 210/1000000
# number of seen frames = 31933
# epsilon = 1
# average reward in episode 210 = 0.0
# done at step 160
# episode 211/1000000
# number of seen frames = 32093
# epsilon = 1
# average reward in episode 211 = 1.0
# done at step 109
# episode 212/1000000
# number of seen frames = 32202
# epsilon = 1
# average reward in episode 212 = 0.0
# done at step 231
# episode 213/1000000
# number of seen frames = 32433
# epsilon = 1
# average reward in episode 213 = 3.0
# done at step 96
# episode 214/1000000
# number of seen frames = 32529
# epsilon = 1
# average reward in episode 214 = 0.0
# done at step 132
# episode 215/1000000
# number of seen frames = 32661
# epsilon = 1
# average reward in episode 215 = 1.0
# done at step 235
# episode 216/1000000
# number of seen frames = 32896
# epsilon = 1
# average reward in episode 216 = 3.0
# done at step 115
# episode 217/1000000
# number of seen frames = 33011
# epsilon = 1
# average reward in episode 217 = 0.0
# done at step 177
# episode 218/1000000
# number of seen frames = 33188
# epsilon = 1
# average reward in episode 218 = 1.0
# done at step 258
# episode 219/1000000
# number of seen frames = 33446
# epsilon = 1
# average reward in episode 219 = 4.0
# done at step 222
# episode 220/1000000
# number of seen frames = 33668
# epsilon = 1
# average reward in episode 220 = 3.0
# done at step 125
# episode 221/1000000
# number of seen frames = 33793
# epsilon = 1
# average reward in episode 221 = 0.0
# done at step 158
# episode 222/1000000
# number of seen frames = 33951
# epsilon = 1
# average reward in episode 222 = 1.0
# done at step 266
# episode 223/1000000
# number of seen frames = 34217
# epsilon = 1
# average reward in episode 223 = 3.0
# done at step 177
# episode 224/1000000
# number of seen frames = 34394
# epsilon = 1
# average reward in episode 224 = 2.0
# done at step 175
# episode 225/1000000
# number of seen frames = 34569
# epsilon = 1
# average reward in episode 225 = 1.0
# done at step 185
# episode 226/1000000
# number of seen frames = 34754
# epsilon = 1
# average reward in episode 226 = 2.0
# done at step 159
# episode 227/1000000
# number of seen frames = 34913
# epsilon = 1
# average reward in episode 227 = 1.0
# done at step 107
# episode 228/1000000
# number of seen frames = 35020
# epsilon = 1
# average reward in episode 228 = 0.0
# done at step 190
# episode 229/1000000
# number of seen frames = 35210
# epsilon = 1
# average reward in episode 229 = 2.0
# done at step 102
# episode 230/1000000
# number of seen frames = 35312
# epsilon = 1
# average reward in episode 230 = 0.0
# done at step 108
# episode 231/1000000
# number of seen frames = 35420
# epsilon = 1
# average reward in episode 231 = 0.0
# done at step 133
# episode 232/1000000
# number of seen frames = 35553
# epsilon = 1
# average reward in episode 232 = 0.0
# done at step 115
# episode 233/1000000
# number of seen frames = 35668
# epsilon = 1
# average reward in episode 233 = 0.0
# done at step 162
# episode 234/1000000
# number of seen frames = 35830
# epsilon = 1
# average reward in episode 234 = 1.0
# done at step 100
# episode 235/1000000
# number of seen frames = 35930
# epsilon = 1
# average reward in episode 235 = 0.0
# done at step 155
# episode 236/1000000
# number of seen frames = 36085
# epsilon = 1
# average reward in episode 236 = 1.0
# done at step 157
# episode 237/1000000
# number of seen frames = 36242
# epsilon = 1
# average reward in episode 237 = 1.0
# done at step 111
# episode 238/1000000
# number of seen frames = 36353
# epsilon = 1
# average reward in episode 238 = 0.0
# done at step 125
# episode 239/1000000
# number of seen frames = 36478
# epsilon = 1
# average reward in episode 239 = 0.0
# done at step 199
# episode 240/1000000
# number of seen frames = 36677
# epsilon = 1
# average reward in episode 240 = 2.0
# done at step 202
# episode 241/1000000
# number of seen frames = 36879
# epsilon = 1
# average reward in episode 241 = 2.0
# done at step 214
# episode 242/1000000
# number of seen frames = 37093
# epsilon = 1
# average reward in episode 242 = 2.0
# done at step 116
# episode 243/1000000
# number of seen frames = 37209
# epsilon = 1
# average reward in episode 243 = 0.0
# done at step 189
# episode 244/1000000
# number of seen frames = 37398
# epsilon = 1
# average reward in episode 244 = 2.0
# done at step 146
# episode 245/1000000
# number of seen frames = 37544
# epsilon = 1
# average reward in episode 245 = 1.0
# done at step 114
# episode 246/1000000
# number of seen frames = 37658
# epsilon = 1
# average reward in episode 246 = 0.0
# done at step 238
# episode 247/1000000
# number of seen frames = 37896
# epsilon = 1
# average reward in episode 247 = 3.0
# done at step 130
# episode 248/1000000
# number of seen frames = 38026
# epsilon = 1
# average reward in episode 248 = 0.0
# done at step 185
# episode 249/1000000
# number of seen frames = 38211
# epsilon = 1
# average reward in episode 249 = 2.0
# done at step 99
# episode 250/1000000
# number of seen frames = 38310
# epsilon = 1
# average reward in episode 250 = 0.0
# done at step 190
# episode 251/1000000
# number of seen frames = 38500
# epsilon = 1
# average reward in episode 251 = 2.0
# done at step 128
# episode 252/1000000
# number of seen frames = 38628
# epsilon = 1
# average reward in episode 252 = 1.0
# done at step 166
# episode 253/1000000
# number of seen frames = 38794
# epsilon = 1
# average reward in episode 253 = 1.0
# done at step 212
# episode 254/1000000
# number of seen frames = 39006
# epsilon = 1
# average reward in episode 254 = 2.0
# done at step 200
# episode 255/1000000
# number of seen frames = 39206
# epsilon = 1
# average reward in episode 255 = 2.0
# done at step 238
# episode 256/1000000
# number of seen frames = 39444
# epsilon = 1
# average reward in episode 256 = 3.0
# done at step 174
# episode 257/1000000
# number of seen frames = 39618
# epsilon = 1
# average reward in episode 257 = 1.0
# done at step 107
# episode 258/1000000
# number of seen frames = 39725
# epsilon = 1
# average reward in episode 258 = 0.0
# done at step 167
# episode 259/1000000
# number of seen frames = 39892
# epsilon = 1
# average reward in episode 259 = 1.0
# done at step 118
# episode 260/1000000
# number of seen frames = 40010
# epsilon = 1
# average reward in episode 260 = 0.0
# done at step 128
# episode 261/1000000
# number of seen frames = 40138
# epsilon = 1
# average reward in episode 261 = 0.0
# done at step 129
# episode 262/1000000
# number of seen frames = 40267
# epsilon = 1
# average reward in episode 262 = 0.0
# done at step 135
# episode 263/1000000
# number of seen frames = 40402
# epsilon = 1
# average reward in episode 263 = 0.0
# done at step 211
# episode 264/1000000
# number of seen frames = 40613
# epsilon = 1
# average reward in episode 264 = 3.0
# done at step 152
# episode 265/1000000
# number of seen frames = 40765
# epsilon = 1
# average reward in episode 265 = 1.0
# done at step 240
# episode 266/1000000
# number of seen frames = 41005
# epsilon = 1
# average reward in episode 266 = 3.0
# done at step 227
# episode 267/1000000
# number of seen frames = 41232
# epsilon = 1
# average reward in episode 267 = 2.0
# done at step 115
# episode 268/1000000
# number of seen frames = 41347
# epsilon = 1
# average reward in episode 268 = 0.0
# done at step 170
# episode 269/1000000
# number of seen frames = 41517
# epsilon = 1
# average reward in episode 269 = 1.0
# done at step 171
# episode 270/1000000
# number of seen frames = 41688
# epsilon = 1
# average reward in episode 270 = 2.0
# done at step 178
# episode 271/1000000
# number of seen frames = 41866
# epsilon = 1
# average reward in episode 271 = 2.0
# done at step 150
# episode 272/1000000
# number of seen frames = 42016
# epsilon = 1
# average reward in episode 272 = 1.0
# done at step 204
# episode 273/1000000
# number of seen frames = 42220
# epsilon = 1
# average reward in episode 273 = 3.0
# done at step 190
# episode 274/1000000
# number of seen frames = 42410
# epsilon = 1
# average reward in episode 274 = 2.0
# done at step 167
# episode 275/1000000
# number of seen frames = 42577
# epsilon = 1
# average reward in episode 275 = 1.0
# done at step 121
# episode 276/1000000
# number of seen frames = 42698
# epsilon = 1
# average reward in episode 276 = 0.0
# done at step 199
# episode 277/1000000
# number of seen frames = 42897
# epsilon = 1
# average reward in episode 277 = 2.0
# done at step 158
# episode 278/1000000
# number of seen frames = 43055
# epsilon = 1
# average reward in episode 278 = 1.0
# done at step 165
# episode 279/1000000
# number of seen frames = 43220
# epsilon = 1
# average reward in episode 279 = 1.0
# done at step 247
# episode 280/1000000
# number of seen frames = 43467
# epsilon = 1
# average reward in episode 280 = 4.0
# done at step 139
# episode 281/1000000
# number of seen frames = 43606
# epsilon = 1
# average reward in episode 281 = 0.0
# done at step 129
# episode 282/1000000
# number of seen frames = 43735
# epsilon = 1
# average reward in episode 282 = 1.0
# done at step 133
# episode 283/1000000
# number of seen frames = 43868
# epsilon = 1
# average reward in episode 283 = 0.0
# done at step 127
# episode 284/1000000
# number of seen frames = 43995
# epsilon = 1
# average reward in episode 284 = 0.0
# done at step 182
# episode 285/1000000
# number of seen frames = 44177
# epsilon = 1
# average reward in episode 285 = 2.0
# done at step 120
# episode 286/1000000
# number of seen frames = 44297
# epsilon = 1
# average reward in episode 286 = 0.0
# done at step 190
# episode 287/1000000
# number of seen frames = 44487
# epsilon = 1
# average reward in episode 287 = 2.0
# done at step 100
# episode 288/1000000
# number of seen frames = 44587
# epsilon = 1
# average reward in episode 288 = 0.0
# done at step 118
# episode 289/1000000
# number of seen frames = 44705
# epsilon = 1
# average reward in episode 289 = 0.0
# done at step 156
# episode 290/1000000
# number of seen frames = 44861
# epsilon = 1
# average reward in episode 290 = 1.0
# done at step 123
# episode 291/1000000
# number of seen frames = 44984
# epsilon = 1
# average reward in episode 291 = 0.0
# done at step 228
# episode 292/1000000
# number of seen frames = 45212
# epsilon = 1
# average reward in episode 292 = 3.0
# done at step 103
# episode 293/1000000
# number of seen frames = 45315
# epsilon = 1
# average reward in episode 293 = 0.0
# done at step 97
# episode 294/1000000
# number of seen frames = 45412
# epsilon = 1
# average reward in episode 294 = 0.0
# done at step 212
# episode 295/1000000
# number of seen frames = 45624
# epsilon = 1
# average reward in episode 295 = 3.0
# done at step 193
# episode 296/1000000
# number of seen frames = 45817
# epsilon = 1
# average reward in episode 296 = 2.0
# done at step 182
# episode 297/1000000
# number of seen frames = 45999
# epsilon = 1
# average reward in episode 297 = 1.0
# done at step 149
# episode 298/1000000
# number of seen frames = 46148
# epsilon = 1
# average reward in episode 298 = 1.0
# done at step 137
# episode 299/1000000
# number of seen frames = 46285
# epsilon = 1
# average reward in episode 299 = 1.0
# done at step 221
# episode 300/1000000
# number of seen frames = 46506
# epsilon = 1
# average reward in episode 300 = 2.0
# done at step 114
# episode 301/1000000
# number of seen frames = 46620
# epsilon = 1
# average reward in episode 301 = 0.0
# done at step 151
# episode 302/1000000
# number of seen frames = 46771
# epsilon = 1
# average reward in episode 302 = 1.0
# done at step 117
# episode 303/1000000
# number of seen frames = 46888
# epsilon = 1
# average reward in episode 303 = 0.0
# done at step 111
# episode 304/1000000
# number of seen frames = 46999
# epsilon = 1
# average reward in episode 304 = 0.0
# done at step 126
# episode 305/1000000
# number of seen frames = 47125
# epsilon = 1
# average reward in episode 305 = 0.0
# done at step 199
# episode 306/1000000
# number of seen frames = 47324
# epsilon = 1
# average reward in episode 306 = 3.0
# done at step 156
# episode 307/1000000
# number of seen frames = 47480
# epsilon = 1
# average reward in episode 307 = 1.0
# done at step 189
# episode 308/1000000
# number of seen frames = 47669
# epsilon = 1
# average reward in episode 308 = 2.0
# done at step 189
# episode 309/1000000
# number of seen frames = 47858
# epsilon = 1
# average reward in episode 309 = 2.0
# done at step 144
# episode 310/1000000
# number of seen frames = 48002
# epsilon = 1
# average reward in episode 310 = 1.0
# done at step 118
# episode 311/1000000
# number of seen frames = 48120
# epsilon = 1
# average reward in episode 311 = 0.0
# done at step 252
# episode 312/1000000
# number of seen frames = 48372
# epsilon = 1
# average reward in episode 312 = 3.0
# done at step 170
# episode 313/1000000
# number of seen frames = 48542
# epsilon = 1
# average reward in episode 313 = 1.0
# done at step 115
# episode 314/1000000
# number of seen frames = 48657
# epsilon = 1
# average reward in episode 314 = 0.0
# done at step 155
# episode 315/1000000
# number of seen frames = 48812
# epsilon = 1
# average reward in episode 315 = 1.0
# done at step 127
# episode 316/1000000
# number of seen frames = 48939
# epsilon = 1
# average reward in episode 316 = 0.0
# done at step 124
# episode 317/1000000
# number of seen frames = 49063
# epsilon = 1
# average reward in episode 317 = 0.0
# done at step 123
# episode 318/1000000
# number of seen frames = 49186
# epsilon = 1
# average reward in episode 318 = 0.0
# done at step 200
# episode 319/1000000
# number of seen frames = 49386
# epsilon = 1
# average reward in episode 319 = 2.0
# done at step 136
# episode 320/1000000
# number of seen frames = 49522
# epsilon = 1
# average reward in episode 320 = 1.0
# done at step 213
# episode 321/1000000
# number of seen frames = 49735
# epsilon = 1
# average reward in episode 321 = 2.0
# done at step 191
# episode 322/1000000
# number of seen frames = 49926
# epsilon = 1
# average reward in episode 322 = 1.0
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# done at step 238
# episode 323/1000000
# number of seen frames = 50164
# epsilon = 0.9998524000000049
# average reward in episode 323 = 3.0
# done at step 121
# episode 324/1000000
# number of seen frames = 50285
# epsilon = 0.9997435000000084
# average reward in episode 324 = 0.0
# done at step 244
# episode 325/1000000
# number of seen frames = 50529
# epsilon = 0.9995239000000157
# average reward in episode 325 = 3.0
# done at step 157
# episode 326/1000000
# number of seen frames = 50686
# epsilon = 0.9993826000000203
# average reward in episode 326 = 1.0
# done at step 120
# episode 327/1000000
# number of seen frames = 50806
# epsilon = 0.9992746000000239
# average reward in episode 327 = 0.0
# done at step 227
# episode 328/1000000
# number of seen frames = 51033
# epsilon = 0.9990703000000306
# average reward in episode 328 = 2.0
# done at step 104
# episode 329/1000000
# number of seen frames = 51137
# epsilon = 0.9989767000000337
# average reward in episode 329 = 0.0
# done at step 146
# episode 330/1000000
# number of seen frames = 51283
# epsilon = 0.998845300000038
# average reward in episode 330 = 1.0
# done at step 216
# episode 331/1000000
# number of seen frames = 51499
# epsilon = 0.9986509000000444
# average reward in episode 331 = 2.0
# done at step 171
# episode 332/1000000
# number of seen frames = 51670
# epsilon = 0.9984970000000495
# average reward in episode 332 = 1.0
# done at step 194
# episode 333/1000000
# number of seen frames = 51864
# epsilon = 0.9983224000000552
# average reward in episode 333 = 2.0
# done at step 193
# episode 334/1000000
# number of seen frames = 52057
# epsilon = 0.998148700000061
# average reward in episode 334 = 2.0
# done at step 148
# episode 335/1000000
# number of seen frames = 52205
# epsilon = 0.9980155000000653
# average reward in episode 335 = 1.0
# done at step 142
# episode 336/1000000
# number of seen frames = 52347
# epsilon = 0.9978877000000695
# average reward in episode 336 = 0.0
# done at step 120
# episode 337/1000000
# number of seen frames = 52467
# epsilon = 0.9977797000000731
# average reward in episode 337 = 0.0
# done at step 266
# episode 338/1000000
# number of seen frames = 52733
# epsilon = 0.997540300000081
# average reward in episode 338 = 3.0
# done at step 117
# episode 339/1000000
# number of seen frames = 52850
# epsilon = 0.9974350000000844
# average reward in episode 339 = 0.0
# done at step 164
# episode 340/1000000
# number of seen frames = 53014
# epsilon = 0.9972874000000893
# average reward in episode 340 = 1.0
# done at step 173
# episode 341/1000000
# number of seen frames = 53187
# epsilon = 0.9971317000000944
# average reward in episode 341 = 2.0
# done at step 198
# episode 342/1000000
# number of seen frames = 53385
# epsilon = 0.9969535000001003
# average reward in episode 342 = 2.0
# done at step 126
# episode 343/1000000
# number of seen frames = 53511
# epsilon = 0.996840100000104
# average reward in episode 343 = 0.0
# done at step 119
# episode 344/1000000
# number of seen frames = 53630
# epsilon = 0.9967330000001076
# average reward in episode 344 = 0.0
# done at step 175
# episode 345/1000000
# number of seen frames = 53805
# epsilon = 0.9965755000001127
# average reward in episode 345 = 2.0
# done at step 121
# episode 346/1000000
# number of seen frames = 53926
# epsilon = 0.9964666000001163
# average reward in episode 346 = 0.0
# done at step 180
# episode 347/1000000
# number of seen frames = 54106
# epsilon = 0.9963046000001217
# average reward in episode 347 = 2.0
# done at step 178
# episode 348/1000000
# number of seen frames = 54284
# epsilon = 0.9961444000001269
# average reward in episode 348 = 1.0
# done at step 239
# episode 349/1000000
# number of seen frames = 54523
# epsilon = 0.995929300000134
# average reward in episode 349 = 4.0
# done at step 226
# episode 350/1000000
# number of seen frames = 54749
# epsilon = 0.9957259000001407
# average reward in episode 350 = 3.0
# done at step 95
# episode 351/1000000
# number of seen frames = 54844
# epsilon = 0.9956404000001435
# average reward in episode 351 = 0.0
# done at step 134
# episode 352/1000000
# number of seen frames = 54978
# epsilon = 0.9955198000001475
# average reward in episode 352 = 0.0
# done at step 132
# episode 353/1000000
# number of seen frames = 55110
# epsilon = 0.9954010000001514
# average reward in episode 353 = 0.0
# done at step 142
# episode 354/1000000
# number of seen frames = 55252
# epsilon = 0.9952732000001556
# average reward in episode 354 = 1.0
# done at step 108
# episode 355/1000000
# number of seen frames = 55360
# epsilon = 0.9951760000001588
# average reward in episode 355 = 0.0
# done at step 135
# episode 356/1000000
# number of seen frames = 55495
# epsilon = 0.9950545000001628
# average reward in episode 356 = 0.0
# done at step 169
# episode 357/1000000
# number of seen frames = 55664
# epsilon = 0.9949024000001678
# average reward in episode 357 = 1.0
# done at step 105
# episode 358/1000000
# number of seen frames = 55769
# epsilon = 0.9948079000001709
# average reward in episode 358 = 0.0
# done at step 122
# episode 359/1000000
# number of seen frames = 55891
# epsilon = 0.9946981000001746
# average reward in episode 359 = 0.0
# done at step 124
# episode 360/1000000
# number of seen frames = 56015
# epsilon = 0.9945865000001782
# average reward in episode 360 = 0.0
# done at step 110
# episode 361/1000000
# number of seen frames = 56125
# epsilon = 0.9944875000001815
# average reward in episode 361 = 0.0
# done at step 114
# episode 362/1000000
# number of seen frames = 56239
# epsilon = 0.9943849000001849
# average reward in episode 362 = 0.0
# done at step 112
# episode 363/1000000
# number of seen frames = 56351
# epsilon = 0.9942841000001882
# average reward in episode 363 = 0.0
# done at step 114
# episode 364/1000000
# number of seen frames = 56465
# epsilon = 0.9941815000001916
# average reward in episode 364 = 0.0
# done at step 122
# episode 365/1000000
# number of seen frames = 56587
# epsilon = 0.9940717000001952
# average reward in episode 365 = 0.0
# done at step 209
# episode 366/1000000
# number of seen frames = 56796
# epsilon = 0.9938836000002014
# average reward in episode 366 = 3.0
# done at step 202
# episode 367/1000000
# number of seen frames = 56998
# epsilon = 0.9937018000002074
# average reward in episode 367 = 2.0
# done at step 136
# episode 368/1000000
# number of seen frames = 57134
# epsilon = 0.9935794000002114
# average reward in episode 368 = 0.0
# done at step 133
# episode 369/1000000
# number of seen frames = 57267
# epsilon = 0.9934597000002153
# average reward in episode 369 = 1.0
# done at step 180
# episode 370/1000000
# number of seen frames = 57447
# epsilon = 0.9932977000002207
# average reward in episode 370 = 2.0
# done at step 137
# episode 371/1000000
# number of seen frames = 57584
# epsilon = 0.9931744000002247
# average reward in episode 371 = 1.0
# done at step 152
# episode 372/1000000
# number of seen frames = 57736
# epsilon = 0.9930376000002292
# average reward in episode 372 = 1.0
# done at step 125
# episode 373/1000000
# number of seen frames = 57861
# epsilon = 0.9929251000002329
# average reward in episode 373 = 0.0
# done at step 168
# episode 374/1000000
# number of seen frames = 58029
# epsilon = 0.9927739000002379
# average reward in episode 374 = 1.0
# done at step 116
# episode 375/1000000
# number of seen frames = 58145
# epsilon = 0.9926695000002413
# average reward in episode 375 = 0.0
# done at step 133
# episode 376/1000000
# number of seen frames = 58278
# epsilon = 0.9925498000002453
# average reward in episode 376 = 0.0
# done at step 130
# episode 377/1000000
# number of seen frames = 58408
# epsilon = 0.9924328000002491
# average reward in episode 377 = 0.0
# done at step 152
# episode 378/1000000
# number of seen frames = 58560
# epsilon = 0.9922960000002536
# average reward in episode 378 = 1.0
# done at step 97
# episode 379/1000000
# number of seen frames = 58657
# epsilon = 0.9922087000002565
# average reward in episode 379 = 0.0
# done at step 175
# episode 380/1000000
# number of seen frames = 58832
# epsilon = 0.9920512000002617
# average reward in episode 380 = 2.0
# done at step 122
# episode 381/1000000
# number of seen frames = 58954
# epsilon = 0.9919414000002653
# average reward in episode 381 = 0.0
# done at step 258
# episode 382/1000000
# number of seen frames = 59212
# epsilon = 0.991709200000273
# average reward in episode 382 = 4.0
# done at step 156
# episode 383/1000000
# number of seen frames = 59368
# epsilon = 0.9915688000002776
# average reward in episode 383 = 1.0
# done at step 191
# episode 384/1000000
# number of seen frames = 59559
# epsilon = 0.9913969000002832
# average reward in episode 384 = 2.0
# done at step 166
# episode 385/1000000
# number of seen frames = 59725
# epsilon = 0.9912475000002882
# average reward in episode 385 = 1.0
# done at step 93
# episode 386/1000000
# number of seen frames = 59818
# epsilon = 0.9911638000002909
# average reward in episode 386 = 0.0
# done at step 97
# episode 387/1000000
# number of seen frames = 59915
# epsilon = 0.9910765000002938
# average reward in episode 387 = 0.0
# done at step 102
# episode 388/1000000
# number of seen frames = 60017
# epsilon = 0.9909847000002968
# average reward in episode 388 = 0.0
# done at step 161
# episode 389/1000000
# number of seen frames = 60178
# epsilon = 0.9908398000003016
# average reward in episode 389 = 1.0
# done at step 198
# episode 390/1000000
# number of seen frames = 60376
# epsilon = 0.9906616000003075
# average reward in episode 390 = 2.0
# done at step 98
# episode 391/1000000
# number of seen frames = 60474
# epsilon = 0.9905734000003104
# average reward in episode 391 = 0.0
# done at step 105
# episode 392/1000000
# number of seen frames = 60579
# epsilon = 0.9904789000003135
# average reward in episode 392 = 0.0
# done at step 129
# episode 393/1000000
# number of seen frames = 60708
# epsilon = 0.9903628000003173
# average reward in episode 393 = 0.0
# done at step 211
# episode 394/1000000
# number of seen frames = 60919
# epsilon = 0.9901729000003235
# average reward in episode 394 = 2.0
# done at step 105
# episode 395/1000000
# number of seen frames = 61024
# epsilon = 0.9900784000003267
# average reward in episode 395 = 0.0
# done at step 170
# episode 396/1000000
# number of seen frames = 61194
# epsilon = 0.9899254000003317
# average reward in episode 396 = 2.0
# done at step 368
# episode 397/1000000
# number of seen frames = 61562
# epsilon = 0.9895942000003426
# average reward in episode 397 = 6.0
# done at step 119
# episode 398/1000000
# number of seen frames = 61681
# epsilon = 0.9894871000003461
# average reward in episode 398 = 0.0
# done at step 256
# episode 399/1000000
# number of seen frames = 61937
# epsilon = 0.9892567000003537
# average reward in episode 399 = 3.0
# done at step 137
# episode 400/1000000
# number of seen frames = 62074
# epsilon = 0.9891334000003578
# average reward in episode 400 = 1.0
# done at step 144
# episode 401/1000000
# number of seen frames = 62218
# epsilon = 0.989003800000362
# average reward in episode 401 = 1.0
# done at step 123
# episode 402/1000000
# number of seen frames = 62341
# epsilon = 0.9888931000003657
# average reward in episode 402 = 0.0
# done at step 118
# episode 403/1000000
# number of seen frames = 62459
# epsilon = 0.9887869000003692
# average reward in episode 403 = 0.0
# done at step 153
# episode 404/1000000
# number of seen frames = 62612
# epsilon = 0.9886492000003737
# ...
# done at step 274
# episode 6476/1000000
# number of seen frames = 1069194
# epsilon = 0.1
# average reward in episode 6476 = 1.0
# done at step 402
# episode 6477/1000000
# number of seen frames = 1069596
# epsilon = 0.1
# average reward in episode 6477 = 1.0
# done at step 162
# episode 6478/1000000
# number of seen frames = 1069758
# epsilon = 0.1
# average reward in episode 6478 = 0.0
# done at step 250
# episode 6479/1000000
# number of seen frames = 1070008
# epsilon = 0.1
# average reward in episode 6479 = 0.0
# done at step 342
# episode 6480/1000000
# number of seen frames = 1070350
# epsilon = 0.1
# average reward in episode 6480 = 0.0
# done at step 352
# episode 6481/1000000
# number of seen frames = 1070702
# epsilon = 0.1
# average reward in episode 6481 = 0.0
# done at step 305
# episode 6482/1000000
# number of seen frames = 1071007
# epsilon = 0.09999910000000001
# average reward in episode 6482 = 1.0
# done at step 344
# episode 6483/1000000
# number of seen frames = 1071351
# epsilon = 0.09999910000000001
# average reward in episode 6483 = 0.0
# done at step 247
# episode 6484/1000000
# number of seen frames = 1071598
# epsilon = 0.1
# average reward in episode 6484 = 0.0
# done at step 233
# episode 6485/1000000
# number of seen frames = 1071831
# epsilon = 0.09999910000000001
# average reward in episode 6485 = 0.0
# done at step 349
# episode 6486/1000000
# number of seen frames = 1072180
# epsilon = 0.1
# average reward in episode 6486 = 0.0
# done at step 191
# episode 6487/1000000
# number of seen frames = 1072371
# epsilon = 0.09999910000000001
# average reward in episode 6487 = 0.0
# done at step 404
# episode 6488/1000000
# number of seen frames = 1072775
# epsilon = 0.09999910000000001
# average reward in episode 6488 = 0.0
# done at step 287
# episode 6489/1000000
# number of seen frames = 1073062
# epsilon = 0.1
# average reward in episode 6489 = 0.0
# done at step 169
# episode 6490/1000000
# number of seen frames = 1073231
# epsilon = 0.09999910000000001
# average reward in episode 6490 = 1.0
# done at step 260
# episode 6491/1000000
# number of seen frames = 1073491
# epsilon = 0.09999910000000001
# average reward in episode 6491 = 0.0
# done at step 215
# episode 6492/1000000
# number of seen frames = 1073706
# epsilon = 0.1
# average reward in episode 6492 = 0.0
# done at step 175
# episode 6493/1000000
# number of seen frames = 1073881
# epsilon = 0.09999910000000001
# average reward in episode 6493 = 0.0
# done at step 232
# episode 6494/1000000
# number of seen frames = 1074113
# epsilon = 0.09999910000000001
# average reward in episode 6494 = 0.0
# done at step 424
# episode 6495/1000000
# number of seen frames = 1074537
# epsilon = 0.09999910000000001
# average reward in episode 6495 = 0.0
# done at step 253
# episode 6496/1000000
# number of seen frames = 1074790
# epsilon = 0.1
# average reward in episode 6496 = 2.0
# done at step 281
# episode 6497/1000000
# number of seen frames = 1075071
# epsilon = 0.09999910000000001
# average reward in episode 6497 = 0.0
# done at step 338
# episode 6498/1000000
# number of seen frames = 1075409
# epsilon = 0.09999910000000001
# average reward in episode 6498 = 1.0
# done at step 390
# episode 6499/1000000
# number of seen frames = 1075799
# epsilon = 0.09999910000000001
# average reward in episode 6499 = 2.0
# done at step 276
# episode 6500/1000000
# number of seen frames = 1076075
# epsilon = 0.09999910000000001
# average reward in episode 6500 = 0.0
# done at step 177
# episode 6501/1000000
# number of seen frames = 1076252
# epsilon = 0.1
# average reward in episode 6501 = 0.0
# done at step 293
# episode 6502/1000000
# number of seen frames = 1076545
# epsilon = 0.09999910000000001
# average reward in episode 6502 = 1.0
# done at step 255
# episode 6503/1000000
# number of seen frames = 1076800
# epsilon = 0.1
# average reward in episode 6503 = 0.0
# done at step 383
# episode 6504/1000000
# number of seen frames = 1077183
# epsilon = 0.09999910000000001
# average reward in episode 6504 = 0.0
# done at step 270
# episode 6505/1000000
# number of seen frames = 1077453
# epsilon = 0.09999910000000001
# average reward in episode 6505 = 0.0
# done at step 201
# episode 6506/1000000
# number of seen frames = 1077654
# epsilon = 0.1
# average reward in episode 6506 = 0.0
# done at step 418
# episode 6507/1000000
# number of seen frames = 1078072
# epsilon = 0.1
# average reward in episode 6507 = 0.0
# done at step 147
# episode 6508/1000000
# number of seen frames = 1078219
# epsilon = 0.09999910000000001
# average reward in episode 6508 = 0.0
# done at step 169
# episode 6509/1000000
# number of seen frames = 1078388
# epsilon = 0.1
# average reward in episode 6509 = 0.0
# done at step 216
# episode 6510/1000000
# number of seen frames = 1078604
# epsilon = 0.1
# average reward in episode 6510 = 1.0
# done at step 213
# episode 6511/1000000
# number of seen frames = 1078817
# epsilon = 0.09999910000000001
# average reward in episode 6511 = 0.0
# done at step 245
# episode 6512/1000000
# number of seen frames = 1079062
# epsilon = 0.1
# average reward in episode 6512 = 0.0
# done at step 176
# episode 6513/1000000
# number of seen frames = 1079238
# epsilon = 0.1
# average reward in episode 6513 = 2.0
# done at step 156
# episode 6514/1000000
# number of seen frames = 1079394
# epsilon = 0.1
# average reward in episode 6514 = 0.0
# done at step 253
# episode 6515/1000000
# number of seen frames = 1079647
# epsilon = 0.09999910000000001
# average reward in episode 6515 = 0.0
# done at step 237
# episode 6516/1000000
# number of seen frames = 1079884
# epsilon = 0.1
# average reward in episode 6516 = 0.0
# done at step 328
# episode 6517/1000000
# number of seen frames = 1080212
# epsilon = 0.1
# average reward in episode 6517 = 0.0
# done at step 225
# episode 6518/1000000
# number of seen frames = 1080437
# epsilon = 0.09999910000000001
# average reward in episode 6518 = 0.0
# done at step 253
# episode 6519/1000000
# number of seen frames = 1080690
# epsilon = 0.1
# average reward in episode 6519 = 0.0
# done at step 335
# episode 6520/1000000
# number of seen frames = 1081025
# epsilon = 0.09999910000000001
# average reward in episode 6520 = 0.0
# done at step 304
# episode 6521/1000000
# number of seen frames = 1081329
# epsilon = 0.09999910000000001
# average reward in episode 6521 = 0.0
# done at step 261
# episode 6522/1000000
# number of seen frames = 1081590
# epsilon = 0.1
# average reward in episode 6522 = 0.0
# done at step 167
# episode 6523/1000000
# number of seen frames = 1081757
# epsilon = 0.09999910000000001
# average reward in episode 6523 = 0.0
# done at step 279
# episode 6524/1000000
# number of seen frames = 1082036
# epsilon = 0.1
# average reward in episode 6524 = 0.0
# done at step 113
# episode 6525/1000000
# number of seen frames = 1082149
# epsilon = 0.09999910000000001
# average reward in episode 6525 = 0.0
# done at step 198
# episode 6526/1000000
# number of seen frames = 1082347
# epsilon = 0.09999910000000001
# average reward in episode 6526 = 0.0
# done at step 205
# episode 6527/1000000
# number of seen frames = 1082552
# epsilon = 0.1
# average reward in episode 6527 = 0.0
# done at step 224
# episode 6528/1000000
# number of seen frames = 1082776
# epsilon = 0.1
# average reward in episode 6528 = 0.0
# done at step 322
# episode 6529/1000000
# number of seen frames = 1083098
# epsilon = 0.1
# average reward in episode 6529 = 0.0
# done at step 246
# episode 6530/1000000
# number of seen frames = 1083344
# epsilon = 0.1
# average reward in episode 6530 = 0.0
# done at step 233
# episode 6531/1000000
# number of seen frames = 1083577
# epsilon = 0.09999910000000001
# average reward in episode 6531 = 0.0
# done at step 167
# episode 6532/1000000
# number of seen frames = 1083744
# epsilon = 0.1
# average reward in episode 6532 = 1.0
# done at step 372
# episode 6533/1000000
# number of seen frames = 1084116
# epsilon = 0.1
# average reward in episode 6533 = 1.0
# done at step 293
# episode 6534/1000000
# number of seen frames = 1084409
# epsilon = 0.09999910000000001
# average reward in episode 6534 = 0.0
# done at step 208
# episode 6535/1000000
# number of seen frames = 1084617
# epsilon = 0.09999910000000001
# average reward in episode 6535 = 0.0
# done at step 259
# episode 6536/1000000
# number of seen frames = 1084876
# epsilon = 0.1
# average reward in episode 6536 = 1.0
# done at step 340
# episode 6537/1000000
# number of seen frames = 1085216
# epsilon = 0.1
# average reward in episode 6537 = 0.0
# done at step 323
# episode 6538/1000000
# number of seen frames = 1085539
# epsilon = 0.09999910000000001
# average reward in episode 6538 = 3.0
# done at step 355
# episode 6539/1000000
# number of seen frames = 1085894
# epsilon = 0.1
# average reward in episode 6539 = 0.0
# done at step 217
# episode 6540/1000000
# number of seen frames = 1086111
# epsilon = 0.09999910000000001
# average reward in episode 6540 = 0.0
# done at step 304
# episode 6541/1000000
# number of seen frames = 1086415
# epsilon = 0.09999910000000001
# average reward in episode 6541 = 2.0
# done at step 190
# episode 6542/1000000
# number of seen frames = 1086605
# epsilon = 0.09999910000000001
# average reward in episode 6542 = 0.0
# done at step 259
# episode 6543/1000000
# number of seen frames = 1086864
# epsilon = 0.1
# average reward in episode 6543 = 0.0
# done at step 240
# episode 6544/1000000
# number of seen frames = 1087104
# epsilon = 0.1
# average reward in episode 6544 = 0.0
# done at step 309
# episode 6545/1000000
# number of seen frames = 1087413
# epsilon = 0.09999910000000001
# average reward in episode 6545 = 0.0
# done at step 143
# episode 6546/1000000
# number of seen frames = 1087556
# epsilon = 0.1
# average reward in episode 6546 = 0.0
# done at step 246
# episode 6547/1000000
# number of seen frames = 1087802
# epsilon = 0.1
# average reward in episode 6547 = 0.0
# done at step 318
# episode 6548/1000000
# number of seen frames = 1088120
# epsilon = 0.1
# average reward in episode 6548 = 0.0
# done at step 192
# episode 6549/1000000
# number of seen frames = 1088312
# epsilon = 0.1
# average reward in episode 6549 = 0.0
# done at step 361
# episode 6550/1000000
# number of seen frames = 1088673
# epsilon = 0.09999910000000001
# average reward in episode 6550 = 0.0
# done at step 230
# episode 6551/1000000
# number of seen frames = 1088903
# epsilon = 0.09999910000000001
# average reward in episode 6551 = 0.0
# done at step 466
# episode 6552/1000000
# number of seen frames = 1089369
# epsilon = 0.09999910000000001
# average reward in episode 6552 = 2.0
# done at step 381
# episode 6553/1000000
# number of seen frames = 1089750
# epsilon = 0.1
# average reward in episode 6553 = 0.0
# done at step 175
# episode 6554/1000000
# number of seen frames = 1089925
# epsilon = 0.09999910000000001
# average reward in episode 6554 = 0.0
# done at step 192
# episode 6555/1000000
# number of seen frames = 1090117
# epsilon = 0.09999910000000001
# average reward in episode 6555 = 0.0
# done at step 268
# episode 6556/1000000
# number of seen frames = 1090385
# epsilon = 0.09999910000000001
# average reward in episode 6556 = 0.0
# done at step 291
# episode 6557/1000000
# number of seen frames = 1090676
# epsilon = 0.1
# average reward in episode 6557 = 1.0
# done at step 206
# episode 6558/1000000
# number of seen frames = 1090882
# epsilon = 0.1
# average reward in episode 6558 = 1.0
# done at step 362
# episode 6559/1000000
# number of seen frames = 1091244
# epsilon = 0.1
# average reward in episode 6559 = 0.0
# done at step 241
# episode 6560/1000000
# number of seen frames = 1091485
# epsilon = 0.09999910000000001
# average reward in episode 6560 = 0.0
# done at step 290
# episode 6561/1000000
# number of seen frames = 1091775
# epsilon = 0.09999910000000001
# average reward in episode 6561 = 0.0
# done at step 193
# episode 6562/1000000
# number of seen frames = 1091968
# epsilon = 0.1
# average reward in episode 6562 = 0.0
# done at step 359
# episode 6563/1000000
# number of seen frames = 1092327
# epsilon = 0.09999910000000001
# average reward in episode 6563 = 0.0
# done at step 176
# episode 6564/1000000
# number of seen frames = 1092503
# epsilon = 0.09999910000000001
# average reward in episode 6564 = 1.0
# done at step 418
# episode 6565/1000000
# number of seen frames = 1092921
# epsilon = 0.09999910000000001
# average reward in episode 6565 = 0.0
# done at step 325
# episode 6566/1000000
# number of seen frames = 1093246
# epsilon = 0.1
# average reward in episode 6566 = 0.0
# done at step 186
# episode 6567/1000000
# number of seen frames = 1093432
# epsilon = 0.1
# average reward in episode 6567 = 0.0
# done at step 238
# episode 6568/1000000
# number of seen frames = 1093670
# epsilon = 0.1
# average reward in episode 6568 = 0.0
# done at step 326
# episode 6569/1000000
# number of seen frames = 1093996
# epsilon = 0.1
# average reward in episode 6569 = 0.0
# done at step 308
# episode 6570/1000000
# number of seen frames = 1094304
# epsilon = 0.1
# average reward in episode 6570 = 0.0
# done at step 263
# episode 6571/1000000
# number of seen frames = 1094567
# epsilon = 0.09999910000000001
# average reward in episode 6571 = 0.0
# done at step 184
# episode 6572/1000000
# number of seen frames = 1094751
# epsilon = 0.09999910000000001
# average reward in episode 6572 = 0.0
# done at step 188
# episode 6573/1000000
# number of seen frames = 1094939
# epsilon = 0.09999910000000001
# average reward in episode 6573 = 0.0
# done at step 176
# episode 6574/1000000
# number of seen frames = 1095115
# epsilon = 0.09999910000000001
# average reward in episode 6574 = 0.0
# done at step 253
# episode 6575/1000000
# number of seen frames = 1095368
# epsilon = 0.1
# average reward in episode 6575 = 2.0
# done at step 277
# episode 6576/1000000
# number of seen frames = 1095645
# epsilon = 0.09999910000000001
# average reward in episode 6576 = 0.0
# done at step 144
# episode 6577/1000000
# number of seen frames = 1095789
# epsilon = 0.09999910000000001
# average reward in episode 6577 = 0.0
# done at step 282
# episode 6578/1000000
# number of seen frames = 1096071
# epsilon = 0.09999910000000001
# average reward in episode 6578 = 0.0
# done at step 140
# episode 6579/1000000
# number of seen frames = 1096211
# epsilon = 0.09999910000000001
# average reward in episode 6579 = 0.0
# done at step 323
# episode 6580/1000000
# number of seen frames = 1096534
# epsilon = 0.1
# average reward in episode 6580 = 0.0
# done at step 170
# episode 6581/1000000
# number of seen frames = 1096704
# epsilon = 0.1
# average reward in episode 6581 = 0.0
# done at step 426
# episode 6582/1000000
# number of seen frames = 1097130
# epsilon = 0.1
# average reward in episode 6582 = 0.0
# done at step 204
# episode 6583/1000000
# number of seen frames = 1097334
# epsilon = 0.1
# average reward in episode 6583 = 0.0
# done at step 255
# episode 6584/1000000
# number of seen frames = 1097589
# epsilon = 0.09999910000000001
# average reward in episode 6584 = 0.0
# done at step 406
# episode 6585/1000000
# number of seen frames = 1097995
# epsilon = 0.09999910000000001
# average reward in episode 6585 = 2.0
# done at step 307
# episode 6586/1000000
# number of seen frames = 1098302
# epsilon = 0.1
# average reward in episode 6586 = 0.0
# done at step 260
# episode 6587/1000000
# number of seen frames = 1098562
# epsilon = 0.1
# average reward in episode 6587 = 0.0
# done at step 441
# episode 6588/1000000
# number of seen frames = 1099003
# epsilon = 0.09999910000000001
# average reward in episode 6588 = 1.0
# done at step 386
# episode 6589/1000000
# number of seen frames = 1099389
# epsilon = 0.09999910000000001
# average reward in episode 6589 = 0.0
# done at step 120
# episode 6590/1000000
# number of seen frames = 1099509
# epsilon = 0.09999910000000001
# average reward in episode 6590 = 0.0
# done at step 166
# episode 6591/1000000
# number of seen frames = 1099675
# epsilon = 0.09999910000000001
# average reward in episode 6591 = 0.0
# done at step 329
# episode 6592/1000000
# number of seen frames = 1100004
# epsilon = 0.1
# average reward in episode 6592 = 0.0
# done at step 378
# episode 6593/1000000
# number of seen frames = 1100382
# epsilon = 0.1
# average reward in episode 6593 = 0.0
# done at step 166
# episode 6594/1000000
# number of seen frames = 1100548
# epsilon = 0.1
# average reward in episode 6594 = 0.0
# done at step 283
# episode 6595/1000000
# number of seen frames = 1100831
# epsilon = 0.09999910000000001
# average reward in episode 6595 = 3.0
# done at step 184
# episode 6596/1000000
# number of seen frames = 1101015
# epsilon = 0.09999910000000001
# average reward in episode 6596 = 0.0
# done at step 189
# episode 6597/1000000
# number of seen frames = 1101204
# epsilon = 0.1
# average reward in episode 6597 = 0.0
# done at step 209
# episode 6598/1000000
# number of seen frames = 1101413
# epsilon = 0.09999910000000001
# average reward in episode 6598 = 0.0
# done at step 159
# episode 6599/1000000
# number of seen frames = 1101572
# epsilon = 0.1
# average reward in episode 6599 = 0.0

# %%
#presume training
 
env=gym.make("BreakoutDeterministic-v4")
agent=DDQNAgent(env=env,path="/content/gdrive/My Drive/DDQN_Breakout_V4/10_Huber_target_model_5100.h5")
with open("/content/gdrive/My Drive/DDQN_Breakout_V4/10_Huber_reward_episode_epsilon_5100.pkl", "rb") as fp:
                  my_list=pickle.load(fp)

with open("/content/gdrive/My Drive/DDQN_Breakout_V4/10_Huber_memory_5100.pkl", "rb") as fp2:
                  my_memory=pickle.load(fp2)

with open(F"/content/gdrive/My Drive/DDQN_Breakout_V4/10_Huber_n_seen_frames5100.pkl", "rb") as fp:
                  agent.n_seen_frame=pickle.load(fp)

agent.reward_per_episode=my_list[0]
agent.epsilon=my_list[2]
agent.memory=deque(list(my_memory)[:850000],maxlen=850000)
del(my_memory)

#agent.n_seen_frame=len(agent.memory)
print(agent.epsilon)
print(len(agent.memory))
agent.train_model()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4479: The name tf.truncated_normal is deprecated. Please use tf.random.truncated_normal instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/losses/losses_impl.py:121: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 20, 20, 16)        4112
# _________________________________________________________________
# activation_1 (Activation)    (None, 20, 20, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 9, 9, 32)          8224
# _________________________________________________________________
# activation_2 (Activation)    (None, 9, 9, 32)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2592)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               663808
# _________________________________________________________________
# dense_2 (Dense)              (None, 4)                 1028
# =================================================================
# Total params: 677,172
# Trainable params: 677,172
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_3 (Conv2D)            (None, 20, 20, 16)        4112
# _________________________________________________________________
# activation_3 (Activation)    (None, 20, 20, 16)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 9, 9, 32)          8224
# _________________________________________________________________
# activation_4 (Activation)    (None, 9, 9, 32)          0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 2592)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 256)               663808
# _________________________________________________________________
# dense_4 (Dense)              (None, 4)                 1028
# =================================================================
# Total params: 677,172
# Trainable params: 677,172
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:203: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# 0.1
# 850000
# episode 0/1000000
# number of seen frames = 8893338
# epsilon = 0.1
# average reward in episode 0 = 0
#
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# done at step 368
# episode 1/1000000
# number of seen frames = 8893706
# epsilon = 0.1
# average reward in episode 1 = 0.0
#
#
# done at step 200
# episode 2/1000000
# number of seen frames = 8893906
# epsilon = 0.1
# average reward in episode 2 = 0.0
#
#
# done at step 329
# episode 3/1000000
# number of seen frames = 8894235
# epsilon = 0.09999910000000001
# average reward in episode 3 = 0.0
#
#
# done at step 260
# episode 4/1000000
# number of seen frames = 8894495
# epsilon = 0.09999910000000001
# average reward in episode 4 = 1.0
#
#
# done at step 268
# episode 5/1000000
# number of seen frames = 8894763
# epsilon = 0.09999910000000001
# average reward in episode 5 = 0.0
#
#
# done at step 234
# episode 6/1000000
# number of seen frames = 8894997
# epsilon = 0.09999910000000001
# average reward in episode 6 = 0.0
#
#
# done at step 217
# episode 7/1000000
# number of seen frames = 8895214
# epsilon = 0.1
# average reward in episode 7 = 0.0
#
#
# done at step 428
# episode 8/1000000
# number of seen frames = 8895642
# epsilon = 0.1
# average reward in episode 8 = 7.0
#
#
# done at step 296
# episode 9/1000000
# number of seen frames = 8895938
# epsilon = 0.1
# average reward in episode 9 = 1.0
#
#
# done at step 371
# episode 10/1000000
# number of seen frames = 8896309
# epsilon = 0.09999910000000001
# average reward in episode 10 = 3.0
#
#
# done at step 357
# episode 11/1000000
# number of seen frames = 8896666
# epsilon = 0.1
# average reward in episode 11 = 0.0
#
#
# done at step 549
# episode 12/1000000
# number of seen frames = 8897215
# epsilon = 0.09999910000000001
# average reward in episode 12 = 0.0
#
#
# done at step 245
# episode 13/1000000
# number of seen frames = 8897460
# epsilon = 0.1
# average reward in episode 13 = 0.0
#
#
# done at step 351
# episode 14/1000000
# number of seen frames = 8897811
# epsilon = 0.09999910000000001
# average reward in episode 14 = 0.0
#
#
# done at step 159
# episode 15/1000000
# number of seen frames = 8897970
# epsilon = 0.1
# average reward in episode 15 = 0.0
#
#
# done at step 234
# episode 16/1000000
# number of seen frames = 8898204
# epsilon = 0.1
# average reward in episode 16 = 0.0
#
#
# done at step 216
# episode 17/1000000
# number of seen frames = 8898420
# epsilon = 0.1
# average reward in episode 17 = 0.0
#
#
# done at step 204
# episode 18/1000000
# number of seen frames = 8898624
# epsilon = 0.1
# average reward in episode 18 = 0.0
#
#
# done at step 296
# episode 19/1000000
# number of seen frames = 8898920
# epsilon = 0.1
# average reward in episode 19 = 0.0
#
#
# done at step 187
# episode 20/1000000
# number of seen frames = 8899107
# epsilon = 0.09999910000000001
# average reward in episode 20 = 0.0
#
#
# done at step 496
# episode 21/1000000
# number of seen frames = 8899603
# epsilon = 0.09999910000000001
# average reward in episode 21 = 0.0
#
#
# done at step 257
# episode 22/1000000
# number of seen frames = 8899860
# epsilon = 0.1
# average reward in episode 22 = 0.0
#
#
# done at step 313
# episode 23/1000000
# number of seen frames = 8900173
# epsilon = 0.09999910000000001
# average reward in episode 23 = 0.0
#
#
# done at step 206
# episode 24/1000000
# number of seen frames = 8900379
# epsilon = 0.09999910000000001
# average reward in episode 24 = 0.0
#
#
# done at step 464
# episode 25/1000000
# number of seen frames = 8900843
# epsilon = 0.09999910000000001
# average reward in episode 25 = 1.0
#
#
# done at step 292
# episode 26/1000000
# number of seen frames = 8901135
# epsilon = 0.09999910000000001
# average reward in episode 26 = 0.0
#
#
# done at step 143
# episode 27/1000000
# number of seen frames = 8901278
# epsilon = 0.1
# average reward in episode 27 = 0.0
#
#
# done at step 276
# episode 28/1000000
# number of seen frames = 8901554
# epsilon = 0.1
# average reward in episode 28 = 0.0
#
#
# done at step 264
# episode 29/1000000
# number of seen frames = 8901818
# epsilon = 0.1
# average reward in episode 29 = 0.0
#
#
# done at step 259
# episode 30/1000000
# number of seen frames = 8902077
# epsilon = 0.09999910000000001
# average reward in episode 30 = 0.0
#
#
# done at step 399
# episode 31/1000000
# number of seen frames = 8902476
# epsilon = 0.1
# average reward in episode 31 = 0.0
#
#
# done at step 448
# episode 32/1000000
# number of seen frames = 8902924
# epsilon = 0.1
# average reward in episode 32 = 0.0
#
#
# done at step 215
# episode 33/1000000
# number of seen frames = 8903139
# epsilon = 0.09999910000000001
# average reward in episode 33 = 0.0
#
#
# done at step 172
# episode 34/1000000
# number of seen frames = 8903311
# epsilon = 0.09999910000000001
# average reward in episode 34 = 0.0
#
#
# done at step 272
# episode 35/1000000
# number of seen frames = 8903583
# epsilon = 0.09999910000000001
# average reward in episode 35 = 0.0
#
#
# done at step 282
# episode 36/1000000
# number of seen frames = 8903865
# epsilon = 0.09999910000000001
# average reward in episode 36 = 1.0
#
#
# done at step 291
# episode 37/1000000
# number of seen frames = 8904156
# epsilon = 0.1
# average reward in episode 37 = 1.0
#
#
# done at step 175
# episode 38/1000000
# number of seen frames = 8904331
# epsilon = 0.09999910000000001
# average reward in episode 38 = 0.0
#
#
# done at step 267
# episode 39/1000000
# number of seen frames = 8904598
# epsilon = 0.1
# average reward in episode 39 = 0.0
#
#
# done at step 257
# episode 40/1000000
# number of seen frames = 8904855
# epsilon = 0.09999910000000001
# average reward in episode 40 = 0.0
#
#
# done at step 167
# episode 41/1000000
# number of seen frames = 8905022
# epsilon = 0.1
# average reward in episode 41 = 0.0
#
#
# done at step 284
# episode 42/1000000
# number of seen frames = 8905306
# epsilon = 0.1
# average reward in episode 42 = 1.0
#
#
# done at step 328
# episode 43/1000000
# number of seen frames = 8905634
# epsilon = 0.1
# average reward in episode 43 = 0.0
#
#
# done at step 257
# episode 44/1000000
# number of seen frames = 8905891
# epsilon = 0.09999910000000001
# average reward in episode 44 = 0.0
#
#
# done at step 200
# episode 45/1000000
# number of seen frames = 8906091
# epsilon = 0.09999910000000001
# average reward in episode 45 = 2.0
#
#
# done at step 310
# episode 46/1000000
# number of seen frames = 8906401
# epsilon = 0.09999910000000001
# average reward in episode 46 = 2.0
#
#
# done at step 254
# episode 47/1000000
# number of seen frames = 8906655
# epsilon = 0.09999910000000001
# average reward in episode 47 = 0.0
#
#
# done at step 223
# episode 48/1000000
# number of seen frames = 8906878
# epsilon = 0.1
# average reward in episode 48 = 0.0
#
#
# done at step 279
# episode 49/1000000
# number of seen frames = 8907157
# epsilon = 0.09999910000000001
# average reward in episode 49 = 0.0
#
#
# done at step 180
# episode 50/1000000
# number of seen frames = 8907337
# epsilon = 0.09999910000000001
# average reward in episode 50 = 1.0
#
#
# done at step 253
# episode 51/1000000
# number of seen frames = 8907590
# epsilon = 0.1
# average reward in episode 51 = 0.0
#
#
# done at step 258
# episode 52/1000000
# number of seen frames = 8907848
# epsilon = 0.1
# average reward in episode 52 = 1.0
#
#
# done at step 229
# episode 53/1000000
# number of seen frames = 8908077
# epsilon = 0.09999910000000001
# average reward in episode 53 = 2.0
#
#
# done at step 155
# episode 54/1000000
# number of seen frames = 8908232
# epsilon = 0.1
# average reward in episode 54 = 0.0
#
#
# done at step 349
# episode 55/1000000
# number of seen frames = 8908581
# epsilon = 0.09999910000000001
# average reward in episode 55 = 1.0
#
#
# done at step 307
# episode 56/1000000
# number of seen frames = 8908888
# epsilon = 0.1
# average reward in episode 56 = 0.0
#
#
# done at step 286
# episode 57/1000000
# number of seen frames = 8909174
# epsilon = 0.1
# average reward in episode 57 = 0.0
#
#
# done at step 130
# episode 58/1000000
# number of seen frames = 8909304
# epsilon = 0.1
# average reward in episode 58 = 0.0
#
#
# done at step 189
# episode 59/1000000
# number of seen frames = 8909493
# epsilon = 0.09999910000000001
# average reward in episode 59 = 0.0
#
#
# done at step 253
# episode 60/1000000
# number of seen frames = 8909746
# epsilon = 0.1
# average reward in episode 60 = 0.0
#
#
# done at step 248
# episode 61/1000000
# number of seen frames = 8909994
# epsilon = 0.1
# average reward in episode 61 = 1.0
#
#
# done at step 283
# episode 62/1000000
# number of seen frames = 8910277
# epsilon = 0.09999910000000001
# average reward in episode 62 = 0.0
#
#
# done at step 155
# episode 63/1000000
# number of seen frames = 8910432
# epsilon = 0.1
# average reward in episode 63 = 0.0
#
#
# done at step 217
# episode 64/1000000
# number of seen frames = 8910649
# epsilon = 0.09999910000000001
# average reward in episode 64 = 0.0
#
#
# done at step 244
# episode 65/1000000
# number of seen frames = 8910893
# epsilon = 0.09999910000000001
# average reward in episode 65 = 0.0
#
#
# done at step 223
# episode 66/1000000
# number of seen frames = 8911116
# epsilon = 0.1
# average reward in episode 66 = 0.0
#
#
# done at step 166
# episode 67/1000000
# number of seen frames = 8911282
# epsilon = 0.1
# average reward in episode 67 = 0.0
#
#
# done at step 565
# episode 68/1000000
# number of seen frames = 8911847
# epsilon = 0.09999910000000001
# average reward in episode 68 = 1.0
#
#
# done at step 264
# episode 69/1000000
# number of seen frames = 8912111
# epsilon = 0.09999910000000001
# average reward in episode 69 = 0.0
#
#
# done at step 159
# episode 70/1000000
# number of seen frames = 8912270
# epsilon = 0.1
# average reward in episode 70 = 0.0
#
#
# done at step 338
# episode 71/1000000
# number of seen frames = 8912608
# epsilon = 0.1
# average reward in episode 71 = 2.0
#
#
# done at step 389
# episode 72/1000000
# number of seen frames = 8912997
# epsilon = 0.09999910000000001
# average reward in episode 72 = 0.0
#
#
# done at step 264
# episode 73/1000000
# number of seen frames = 8913261
# epsilon = 0.09999910000000001
# average reward in episode 73 = 2.0
#
#
# done at step 127
# episode 74/1000000
# number of seen frames = 8913388
# epsilon = 0.1
# average reward in episode 74 = 0.0
#
#
# done at step 244
# episode 75/1000000
# number of seen frames = 8913632
# epsilon = 0.1
# average reward in episode 75 = 0.0
#
#
# done at step 283
# episode 76/1000000
# number of seen frames = 8913915
# epsilon = 0.09999910000000001
# average reward in episode 76 = 2.0
#
#
# done at step 143
# episode 77/1000000
# number of seen frames = 8914058
# epsilon = 0.1
# average reward in episode 77 = 0.0
#
#
# done at step 235
# episode 78/1000000
# number of seen frames = 8914293
# epsilon = 0.09999910000000001
# average reward in episode 78 = 0.0
#
#
# done at step 189
# episode 79/1000000
# number of seen frames = 8914482
# epsilon = 0.1
# average reward in episode 79 = 0.0
#
#
# done at step 176
# episode 80/1000000
# number of seen frames = 8914658
# epsilon = 0.1
# average reward in episode 80 = 0.0
#
#
# done at step 215
# episode 81/1000000
# number of seen frames = 8914873
# epsilon = 0.09999910000000001
# average reward in episode 81 = 0.0
#
#
# done at step 272
# episode 82/1000000
# number of seen frames = 8915145
# epsilon = 0.09999910000000001
# average reward in episode 82 = 0.0
#
#
# done at step 241
# episode 83/1000000
# number of seen frames = 8915386
# epsilon = 0.1
# average reward in episode 83 = 0.0
#
#
# done at step 209
# episode 84/1000000
# number of seen frames = 8915595
# epsilon = 0.09999910000000001
# average reward in episode 84 = 0.0
#
#
# done at step 201
# episode 85/1000000
# number of seen frames = 8915796
# epsilon = 0.1
# average reward in episode 85 = 0.0
#
#
# done at step 163
# episode 86/1000000
# number of seen frames = 8915959
# epsilon = 0.09999910000000001
# average reward in episode 86 = 1.0
#
#
# done at step 348
# episode 87/1000000
# number of seen frames = 8916307
# epsilon = 0.09999910000000001
# average reward in episode 87 = 0.0
#
#
# done at step 216
# episode 88/1000000
# number of seen frames = 8916523
# epsilon = 0.09999910000000001
# average reward in episode 88 = 0.0
#
#
# done at step 161
# episode 89/1000000
# number of seen frames = 8916684
# epsilon = 0.1
# average reward in episode 89 = 0.0
#
#
# done at step 255
# episode 90/1000000
# number of seen frames = 8916939
# epsilon = 0.09999910000000001
# average reward in episode 90 = 0.0
#
#
# done at step 158
# episode 91/1000000
# number of seen frames = 8917097
# epsilon = 0.09999910000000001
# average reward in episode 91 = 0.0
#
#
# done at step 164
# episode 92/1000000
# number of seen frames = 8917261
# epsilon = 0.09999910000000001
# average reward in episode 92 = 0.0
#
#
# done at step 302
# episode 93/1000000
# number of seen frames = 8917563
# epsilon = 0.09999910000000001
# average reward in episode 93 = 0.0
#
#
# done at step 289
# episode 94/1000000
# number of seen frames = 8917852
# epsilon = 0.1
# average reward in episode 94 = 1.0
#
#
# done at step 372
# episode 95/1000000
# number of seen frames = 8918224
# epsilon = 0.1
# average reward in episode 95 = 3.0
#
#
# done at step 204
# episode 96/1000000
# number of seen frames = 8918428
# epsilon = 0.1
# average reward in episode 96 = 0.0
#
#
# done at step 275
# episode 97/1000000
# number of seen frames = 8918703
# epsilon = 0.09999910000000001
# average reward in episode 97 = 0.0
#
#
# done at step 302
# episode 98/1000000
# number of seen frames = 8919005
# epsilon = 0.09999910000000001
# average reward in episode 98 = 0.0
#
#
# done at step 404
# episode 99/1000000
# number of seen frames = 8919409
# epsilon = 0.09999910000000001
# average reward in episode 99 = 2.0
#
#
# done at step 156
# episode 100/1000000
# number of seen frames = 8919565
# epsilon = 0.09999910000000001
# average reward in episode 100 = 0.0
#
#
# done at step 210
# episode 101/1000000
# number of seen frames = 8919775
# epsilon = 0.09999910000000001
# average reward in episode 101 = 0.0
#
#
# done at step 343
# episode 102/1000000
# number of seen frames = 8920118
# epsilon = 0.1
# average reward in episode 102 = 0.0
#
#
# done at step 192
# episode 103/1000000
# number of seen frames = 8920310
# epsilon = 0.1
# average reward in episode 103 = 0.0
#
#
# done at step 201
# episode 104/1000000
# number of seen frames = 8920511
# epsilon = 0.09999910000000001
# average reward in episode 104 = 0.0
#
#
# done at step 231
# episode 105/1000000
# number of seen frames = 8920742
# epsilon = 0.1
# average reward in episode 105 = 0.0
#
#
# done at step 384
# episode 106/1000000
# number of seen frames = 8921126
# epsilon = 0.1
# average reward in episode 106 = 2.0
#
#
# done at step 356
# episode 107/1000000
# number of seen frames = 8921482
# epsilon = 0.1
# average reward in episode 107 = 0.0
#
#
# done at step 288
# episode 108/1000000
# number of seen frames = 8921770
# epsilon = 0.1
# average reward in episode 108 = 0.0
#
#
# done at step 321
# episode 109/1000000
# number of seen frames = 8922091
# epsilon = 0.09999910000000001
# average reward in episode 109 = 0.0
#
#
# done at step 177
# episode 110/1000000
# number of seen frames = 8922268
# epsilon = 0.1
# average reward in episode 110 = 0.0
#
#
# done at step 252
# episode 111/1000000
# number of seen frames = 8922520
# epsilon = 0.1
# average reward in episode 111 = 0.0
#
#
# done at step 171
# episode 112/1000000
# number of seen frames = 8922691
# epsilon = 0.09999910000000001
# average reward in episode 112 = 0.0
#
#
# done at step 245
# episode 113/1000000
# number of seen frames = 8922936
# epsilon = 0.1
# average reward in episode 113 = 0.0
#
#
# done at step 136
# episode 114/1000000
# number of seen frames = 8923072
# epsilon = 0.1
# average reward in episode 114 = 0.0
#
#
# done at step 184
# episode 115/1000000
# number of seen frames = 8923256
# epsilon = 0.1
# average reward in episode 115 = 0.0
#
#
# done at step 244
# episode 116/1000000
# number of seen frames = 8923500
# epsilon = 0.1
# average reward in episode 116 = 0.0
#
#
# done at step 173
# episode 117/1000000
# number of seen frames = 8923673
# epsilon = 0.09999910000000001
# average reward in episode 117 = 0.0
#
#
# done at step 128
# episode 118/1000000
# number of seen frames = 8923801
# epsilon = 0.09999910000000001
# average reward in episode 118 = 0.0
#
#
# done at step 308
# episode 119/1000000
# number of seen frames = 8924109
# epsilon = 0.09999910000000001
# average reward in episode 119 = 0.0
#
#
# done at step 195
# episode 120/1000000
# number of seen frames = 8924304
# epsilon = 0.1
# average reward in episode 120 = 0.0
#
#
# done at step 264
# episode 121/1000000
# number of seen frames = 8924568
# epsilon = 0.1
# average reward in episode 121 = 0.0
#
#
# done at step 210
# episode 122/1000000
# number of seen frames = 8924778
# epsilon = 0.1
# average reward in episode 122 = 0.0
#
#
# done at step 361
# episode 123/1000000
# number of seen frames = 8925139
# epsilon = 0.09999910000000001
# average reward in episode 123 = 0.0
#
#
# done at step 285
# episode 124/1000000
# number of seen frames = 8925424
# epsilon = 0.1
# average reward in episode 124 = 0.0
#
#
# done at step 343
# episode 125/1000000
# number of seen frames = 8925767
# epsilon = 0.09999910000000001
# average reward in episode 125 = 0.0
#
#
# done at step 209
# episode 126/1000000
# number of seen frames = 8925976
# epsilon = 0.1
# average reward in episode 126 = 0.0
#
#
# done at step 344
# episode 127/1000000
# number of seen frames = 8926320
# epsilon = 0.1
# average reward in episode 127 = 0.0
#
#
# done at step 242
# episode 128/1000000
# number of seen frames = 8926562
# epsilon = 0.1
# average reward in episode 128 = 0.0
#
#
# done at step 164
# episode 129/1000000
# number of seen frames = 8926726
# epsilon = 0.1
# average reward in episode 129 = 0.0
#
#
# done at step 255
# episode 130/1000000
# number of seen frames = 8926981
# epsilon = 0.09999910000000001
# average reward in episode 130 = 0.0
#
#
# done at step 254
# episode 131/1000000
# number of seen frames = 8927235
# epsilon = 0.09999910000000001
# average reward in episode 131 = 0.0
#
#
# done at step 219
# episode 132/1000000
# number of seen frames = 8927454
# epsilon = 0.1
# average reward in episode 132 = 1.0
#
#
# done at step 218
# episode 133/1000000
# number of seen frames = 8927672
# epsilon = 0.1
# average reward in episode 133 = 0.0
#
#
# done at step 230
# episode 134/1000000
# number of seen frames = 8927902
# epsilon = 0.1
# average reward in episode 134 = 0.0
#
#
# done at step 208
# episode 135/1000000
# number of seen frames = 8928110
# epsilon = 0.1
# average reward in episode 135 = 0.0
#
#
# done at step 242
# episode 136/1000000
# number of seen frames = 8928352
# epsilon = 0.1
# average reward in episode 136 = 0.0
#
#
# done at step 293
# episode 137/1000000
# number of seen frames = 8928645
# epsilon = 0.09999910000000001
# average reward in episode 137 = 0.0
#
#
# done at step 183
# episode 138/1000000
# number of seen frames = 8928828
# epsilon = 0.1
# average reward in episode 138 = 0.0
#
#
# done at step 201
# episode 139/1000000
# number of seen frames = 8929029
# epsilon = 0.09999910000000001
# average reward in episode 139 = 1.0
#
#
# done at step 249
# episode 140/1000000
# number of seen frames = 8929278
# epsilon = 0.1
# average reward in episode 140 = 1.0
#
#
# done at step 185
# episode 141/1000000
# number of seen frames = 8929463
# epsilon = 0.09999910000000001
# average reward in episode 141 = 0.0
#
#
# done at step 218
# episode 142/1000000
# number of seen frames = 8929681
# epsilon = 0.09999910000000001
# average reward in episode 142 = 0.0
#
#
# done at step 122
# episode 143/1000000
# number of seen frames = 8929803
# epsilon = 0.09999910000000001
# average reward in episode 143 = 0.0
#
#
# done at step 213
# episode 144/1000000
# number of seen frames = 8930016
# epsilon = 0.1
# average reward in episode 144 = 1.0
#
#
# done at step 221
# episode 145/1000000
# number of seen frames = 8930237
# epsilon = 0.09999910000000001
# average reward in episode 145 = 0.0
#
#
# done at step 239
# episode 146/1000000
# number of seen frames = 8930476
# epsilon = 0.1
# average reward in episode 146 = 2.0
#
#
# done at step 293
# episode 147/1000000
# number of seen frames = 8930769
# epsilon = 0.09999910000000001
# average reward in episode 147 = 1.0
#
#
# done at step 318
# episode 148/1000000
# number of seen frames = 8931087
# epsilon = 0.09999910000000001
# average reward in episode 148 = 0.0
#
#
# done at step 278
# episode 149/1000000
# number of seen frames = 8931365
# epsilon = 0.09999910000000001
# average reward in episode 149 = 0.0
#
#
# done at step 211
# episode 150/1000000
# number of seen frames = 8931576
# epsilon = 0.1
# average reward in episode 150 = 0.0
#
#
# done at step 273
# episode 151/1000000
# number of seen frames = 8931849
# epsilon = 0.09999910000000001
# average reward in episode 151 = 0.0
#
#
# done at step 323
# episode 152/1000000
# number of seen frames = 8932172
# epsilon = 0.1
# average reward in episode 152 = 0.0
#
#
# done at step 259
# episode 153/1000000
# number of seen frames = 8932431
# epsilon = 0.09999910000000001
# average reward in episode 153 = 0.0
#
#
# done at step 199
# episode 154/1000000
# number of seen frames = 8932630
# epsilon = 0.1
# average reward in episode 154 = 0.0
#
#
# done at step 237
# episode 155/1000000
# number of seen frames = 8932867
# epsilon = 0.09999910000000001
# average reward in episode 155 = 0.0
#
#
# done at step 215
# episode 156/1000000
# number of seen frames = 8933082
# epsilon = 0.1
# average reward in episode 156 = 0.0
#
#
# done at step 243
# episode 157/1000000
# number of seen frames = 8933325
# epsilon = 0.09999910000000001
# average reward in episode 157 = 0.0
#
#
# done at step 177
# episode 158/1000000
# number of seen frames = 8933502
# epsilon = 0.1
# average reward in episode 158 = 0.0
#
#
# done at step 293
# episode 159/1000000
# number of seen frames = 8933795
# epsilon = 0.09999910000000001
# average reward in episode 159 = 0.0
#
#
# done at step 152
# episode 160/1000000
# number of seen frames = 8933947
# epsilon = 0.09999910000000001
# average reward in episode 160 = 0.0
#
#
# done at step 333
# episode 161/1000000
# number of seen frames = 8934280
# epsilon = 0.1
# average reward in episode 161 = 1.0
#
#
# done at step 132
# episode 162/1000000
# number of seen frames = 8934412
# epsilon = 0.1
# average reward in episode 162 = 0.0
#
#
# done at step 309
# episode 163/1000000
# number of seen frames = 8934721
# epsilon = 0.09999910000000001
# average reward in episode 163 = 0.0
#
#
# done at step 317
# episode 164/1000000
# number of seen frames = 8935038
# epsilon = 0.1
# average reward in episode 164 = 0.0
#
#
# done at step 177
# episode 165/1000000
# number of seen frames = 8935215
# epsilon = 0.09999910000000001
# average reward in episode 165 = 1.0
#
#
# done at step 215
# episode 166/1000000
# number of seen frames = 8935430
# epsilon = 0.1
# average reward in episode 166 = 0.0
#
#
# done at step 167
# episode 167/1000000
# number of seen frames = 8935597
# epsilon = 0.09999910000000001
# average reward in episode 167 = 0.0
#
#
# done at step 214
# episode 168/1000000
# number of seen frames = 8935811
# epsilon = 0.09999910000000001
# average reward in episode 168 = 0.0
#
#
# done at step 170
# episode 169/1000000
# number of seen frames = 8935981
# epsilon = 0.09999910000000001
# average reward in episode 169 = 1.0
#
#
# done at step 226
# episode 170/1000000
# number of seen frames = 8936207
# epsilon = 0.09999910000000001
# average reward in episode 170 = 0.0
#
#
# done at step 279
# episode 171/1000000
# number of seen frames = 8936486
# epsilon = 0.1
# average reward in episode 171 = 2.0
#
#
# done at step 194
# episode 172/1000000
# number of seen frames = 8936680
# epsilon = 0.1
# average reward in episode 172 = 0.0
#
#
# done at step 321
# episode 173/1000000
# number of seen frames = 8937001
# epsilon = 0.09999910000000001
# average reward in episode 173 = 0.0
#
#
# done at step 196
# episode 174/1000000
# number of seen frames = 8937197
# epsilon = 0.09999910000000001
# average reward in episode 174 = 0.0
#
#
# done at step 230
# episode 175/1000000
# number of seen frames = 8937427
# epsilon = 0.09999910000000001
# average reward in episode 175 = 0.0
#
#
# done at step 364
# episode 176/1000000
# number of seen frames = 8937791
# epsilon = 0.09999910000000001
# average reward in episode 176 = 0.0
#
#
# done at step 169
# episode 177/1000000
# number of seen frames = 8937960
# epsilon = 0.1
# average reward in episode 177 = 0.0
#
#
# done at step 216
# episode 178/1000000
# number of seen frames = 8938176
# epsilon = 0.1
# average reward in episode 178 = 0.0
#
#
# done at step 474
# episode 179/1000000
# number of seen frames = 8938650
# epsilon = 0.1
# average reward in episode 179 = 1.0
#
#
# done at step 164
# episode 180/1000000
# number of seen frames = 8938814
# epsilon = 0.1
# average reward in episode 180 = 0.0
#
#
# done at step 159
# episode 181/1000000
# number of seen frames = 8938973
# epsilon = 0.09999910000000001
# average reward in episode 181 = 0.0
#
#
# done at step 222
# episode 182/1000000
# number of seen frames = 8939195
# epsilon = 0.09999910000000001
# average reward in episode 182 = 1.0
#
#
# done at step 286
# episode 183/1000000
# number of seen frames = 8939481
# epsilon = 0.09999910000000001
# average reward in episode 183 = 0.0
#
#
# done at step 301
# episode 184/1000000
# number of seen frames = 8939782
# epsilon = 0.1
# average reward in episode 184 = 0.0
#
#
# done at step 198
# episode 185/1000000
# number of seen frames = 8939980
# epsilon = 0.1
# average reward in episode 185 = 0.0
#
#
# done at step 194
# episode 186/1000000
# number of seen frames = 8940174
# epsilon = 0.1
# average reward in episode 186 = 0.0
#
#
# done at step 352
# episode 187/1000000
# number of seen frames = 8940526
# epsilon = 0.1
# average reward in episode 187 = 0.0
#
#
# done at step 328
# episode 188/1000000
# number of seen frames = 8940854
# epsilon = 0.1
# average reward in episode 188 = 1.0
#
#
# done at step 266
# episode 189/1000000
# number of seen frames = 8941120
# epsilon = 0.1
# average reward in episode 189 = 0.0
#
#
# done at step 265
# episode 190/1000000
# number of seen frames = 8941385
# epsilon = 0.09999910000000001
# average reward in episode 190 = 0.0
#
#
# done at step 423
# episode 191/1000000
# number of seen frames = 8941808
# epsilon = 0.1
# average reward in episode 191 = 0.0
#
#
# done at step 402
# episode 192/1000000
# number of seen frames = 8942210
# epsilon = 0.1
# average reward in episode 192 = 0.0
#
#
# done at step 340
# episode 193/1000000
# number of seen frames = 8942550
# epsilon = 0.1
# average reward in episode 193 = 1.0
#
#
# done at step 366
# episode 194/1000000
# number of seen frames = 8942916
# epsilon = 0.1
# average reward in episode 194 = 0.0
#
#
# done at step 290
# episode 195/1000000
# number of seen frames = 8943206
# epsilon = 0.1
# average reward in episode 195 = 1.0
#
#
# done at step 477
# episode 196/1000000
# number of seen frames = 8943683
# epsilon = 0.09999910000000001
# average reward in episode 196 = 0.0
#
#
# done at step 215
# episode 197/1000000
# number of seen frames = 8943898
# epsilon = 0.1
# average reward in episode 197 = 0.0
#
#
# done at step 280
# episode 198/1000000
# number of seen frames = 8944178
# epsilon = 0.1
# average reward in episode 198 = 0.0
#
#
# done at step 249
# episode 199/1000000
# number of seen frames = 8944427
# epsilon = 0.09999910000000001
# average reward in episode 199 = 0.0
#
#
# done at step 309
# episode 200/1000000
# number of seen frames = 8944736
# epsilon = 0.1
# average reward in episode 200 = 0.0
#
#
# done at step 169
# episode 201/1000000
# number of seen frames = 8944905
# epsilon = 0.09999910000000001
# average reward in episode 201 = 0.0
#
#
# done at step 283
# episode 202/1000000
# number of seen frames = 8945188
# epsilon = 0.1
# average reward in episode 202 = 0.0
#
#
# done at step 583
# episode 203/1000000
# number of seen frames = 8945771
# epsilon = 0.09999910000000001
# average reward in episode 203 = 4.0
#
#
# done at step 253
# episode 204/1000000
# number of seen frames = 8946024
# epsilon = 0.1
# average reward in episode 204 = 3.0
#
#
# done at step 308
# episode 205/1000000
# number of seen frames = 8946332
# epsilon = 0.1
# average reward in episode 205 = 1.0
#
#
# done at step 294
# episode 206/1000000
# number of seen frames = 8946626
# epsilon = 0.1
# average reward in episode 206 = 0.0
#
#
# done at step 301
# episode 207/1000000
# number of seen frames = 8946927
# epsilon = 0.09999910000000001
# average reward in episode 207 = 0.0
#
#
# done at step 270
# episode 208/1000000
# number of seen frames = 8947197
# epsilon = 0.09999910000000001
# average reward in episode 208 = 0.0
#
#
# done at step 212
# episode 209/1000000
# number of seen frames = 8947409
# epsilon = 0.09999910000000001
# average reward in episode 209 = 0.0
#
#
# done at step 317
# episode 210/1000000
# number of seen frames = 8947726
# epsilon = 0.1
# average reward in episode 210 = 0.0
#
#
# done at step 131
# episode 211/1000000
# number of seen frames = 8947857
# epsilon = 0.09999910000000001
# average reward in episode 211 = 0.0
#
#
# done at step 252
# episode 212/1000000
# number of seen frames = 8948109
# epsilon = 0.09999910000000001
# average reward in episode 212 = 0.0
#
#
# done at step 284
# episode 213/1000000
# number of seen frames = 8948393
# epsilon = 0.09999910000000001
# average reward in episode 213 = 0.0
#
#
# done at step 242
# episode 214/1000000
# number of seen frames = 8948635
# epsilon = 0.09999910000000001
# average reward in episode 214 = 0.0
#
#
# done at step 248
# episode 215/1000000
# number of seen frames = 8948883
# epsilon = 0.09999910000000001
# average reward in episode 215 = 0.0
#
#
# done at step 191
# episode 216/1000000
# number of seen frames = 8949074
# epsilon = 0.1
# average reward in episode 216 = 0.0
#
#
# done at step 300
# episode 217/1000000
# number of seen frames = 8949374
# epsilon = 0.1
# average reward in episode 217 = 0.0
#
#
# done at step 223
# episode 218/1000000
# number of seen frames = 8949597
# epsilon = 0.09999910000000001
# average reward in episode 218 = 0.0
#
#
# done at step 215
# episode 219/1000000
# number of seen frames = 8949812
# epsilon = 0.1
# average reward in episode 219 = 0.0
#
#
# done at step 401
# episode 220/1000000
# number of seen frames = 8950213
# epsilon = 0.09999910000000001
# average reward in episode 220 = 1.0
#
#
# done at step 439
# episode 221/1000000
# number of seen frames = 8950652
# epsilon = 0.1
# average reward in episode 221 = 0.0
#
#
# done at step 178
# episode 222/1000000
# number of seen frames = 8950830
# epsilon = 0.1
# average reward in episode 222 = 0.0
#
#
# done at step 336
# episode 223/1000000
# number of seen frames = 8951166
# epsilon = 0.1
# average reward in episode 223 = 0.0
#
#
# done at step 332
# episode 224/1000000
# number of seen frames = 8951498
# epsilon = 0.1
# average reward in episode 224 = 0.0
#
#
# done at step 161
# episode 225/1000000
# number of seen frames = 8951659
# epsilon = 0.09999910000000001
# average reward in episode 225 = 0.0
#
#
# done at step 232
# episode 226/1000000
# number of seen frames = 8951891
# epsilon = 0.09999910000000001
# average reward in episode 226 = 1.0
#
#
# done at step 329
# episode 227/1000000
# number of seen frames = 8952220
# epsilon = 0.1
# average reward in episode 227 = 2.0
#
#
# done at step 176
# episode 228/1000000
# number of seen frames = 8952396
# epsilon = 0.1
# average reward in episode 228 = 0.0
#
#
# done at step 332
# episode 229/1000000
# number of seen frames = 8952728
# epsilon = 0.1
# average reward in episode 229 = 0.0
#
#
# done at step 236
# episode 230/1000000
# number of seen frames = 8952964
# epsilon = 0.1
# average reward in episode 230 = 0.0
#
#
# done at step 278
# episode 231/1000000
# number of seen frames = 8953242
# epsilon = 0.1
# average reward in episode 231 = 0.0
#
#
# done at step 226
# episode 232/1000000
# number of seen frames = 8953468
# epsilon = 0.1
# average reward in episode 232 = 0.0
#
#
# done at step 206
# episode 233/1000000
# number of seen frames = 8953674
# epsilon = 0.1
# average reward in episode 233 = 0.0
#
#
# done at step 324
# episode 234/1000000
# number of seen frames = 8953998
# epsilon = 0.1
# average reward in episode 234 = 0.0
#
#
# done at step 280
# episode 235/1000000
# number of seen frames = 8954278
# epsilon = 0.1
# average reward in episode 235 = 1.0
#
#
# done at step 199
# episode 236/1000000
# number of seen frames = 8954477
# epsilon = 0.09999910000000001
# average reward in episode 236 = 0.0
#
#
# done at step 190
# episode 237/1000000
# number of seen frames = 8954667
# epsilon = 0.09999910000000001
# average reward in episode 237 = 0.0
#
#
# done at step 344
# episode 238/1000000
# number of seen frames = 8955011
# epsilon = 0.09999910000000001
# average reward in episode 238 = 1.0
#
#
# done at step 280
# episode 239/1000000
# number of seen frames = 8955291
# epsilon = 0.09999910000000001
# average reward in episode 239 = 0.0
#
#
# done at step 131
# episode 240/1000000
# number of seen frames = 8955422
# epsilon = 0.1
# average reward in episode 240 = 0.0
#
#
# done at step 290
# episode 241/1000000
# number of seen frames = 8955712
# epsilon = 0.1
# average reward in episode 241 = 0.0
#
#
# done at step 346
# episode 242/1000000
# number of seen frames = 8956058
# epsilon = 0.1
# average reward in episode 242 = 3.0
#
#
# done at step 222
# episode 243/1000000
# number of seen frames = 8956280
# epsilon = 0.1
# average reward in episode 243 = 0.0
#
#
# done at step 166
# episode 244/1000000
# number of seen frames = 8956446
# epsilon = 0.1
# average reward in episode 244 = 0.0
#
#
# done at step 321
# episode 245/1000000
# number of seen frames = 8956767
# epsilon = 0.09999910000000001
# average reward in episode 245 = 0.0
#
#
# done at step 221
# episode 246/1000000
# number of seen frames = 8956988
# epsilon = 0.1
# average reward in episode 246 = 0.0
#
#
# done at step 273
# episode 247/1000000
# number of seen frames = 8957261
# epsilon = 0.09999910000000001
# average reward in episode 247 = 0.0
#
#
# done at step 196
# episode 248/1000000
# number of seen frames = 8957457
# epsilon = 0.09999910000000001
# average reward in episode 248 = 0.0
#
#
# done at step 272
# episode 249/1000000
# number of seen frames = 8957729
# epsilon = 0.09999910000000001
# average reward in episode 249 = 0.0
#
#
# done at step 311
# episode 250/1000000
# number of seen frames = 8958040
# epsilon = 0.1
# average reward in episode 250 = 2.0
#
#
# done at step 232
# episode 251/1000000
# number of seen frames = 8958272
# epsilon = 0.1
# average reward in episode 251 = 0.0
#
#
# done at step 267
# episode 252/1000000
# number of seen frames = 8958539
# epsilon = 0.09999910000000001
# average reward in episode 252 = 1.0
#
#
# done at step 210
# episode 253/1000000
# number of seen frames = 8958749
# epsilon = 0.09999910000000001
# average reward in episode 253 = 0.0
#
#
# done at step 302
# episode 254/1000000
# number of seen frames = 8959051
# epsilon = 0.09999910000000001
# average reward in episode 254 = 0.0
#
#
# done at step 276
# episode 255/1000000
# number of seen frames = 8959327
# epsilon = 0.09999910000000001
# average reward in episode 255 = 2.0
#
#
# done at step 273
# episode 256/1000000
# number of seen frames = 8959600
# epsilon = 0.1
# average reward in episode 256 = 0.0
#
#
# done at step 340
# episode 257/1000000
# number of seen frames = 8959940
# epsilon = 0.1
# average reward in episode 257 = 1.0
#
#
# done at step 306
# episode 258/1000000
# number of seen frames = 8960246
# epsilon = 0.1
# average reward in episode 258 = 0.0
#
#
# done at step 251
# episode 259/1000000
# number of seen frames = 8960497
# epsilon = 0.09999910000000001
# average reward in episode 259 = 0.0
#
#
# done at step 223
# episode 260/1000000
# number of seen frames = 8960720
# epsilon = 0.1
# average reward in episode 260 = 1.0
#
#
# done at step 295
# episode 261/1000000
# number of seen frames = 8961015
# epsilon = 0.09999910000000001
# average reward in episode 261 = 2.0
#
#
# done at step 179
# episode 262/1000000
# number of seen frames = 8961194
# epsilon = 0.1
# average reward in episode 262 = 0.0
#
#
# done at step 235
# episode 263/1000000
# number of seen frames = 8961429
# epsilon = 0.09999910000000001
# average reward in episode 263 = 0.0
#
#
# done at step 253
# episode 264/1000000
# number of seen frames = 8961682
# epsilon = 0.1
# average reward in episode 264 = 1.0
#
#
# done at step 154
# episode 265/1000000
# number of seen frames = 8961836
# epsilon = 0.1
# average reward in episode 265 = 0.0
#
#
# done at step 270
# episode 266/1000000
# number of seen frames = 8962106
# epsilon = 0.1
# average reward in episode 266 = 0.0
#
#
# done at step 185
# episode 267/1000000
# number of seen frames = 8962291
# epsilon = 0.09999910000000001
# average reward in episode 267 = 0.0
#
#
# done at step 387
# episode 268/1000000
# number of seen frames = 8962678
# epsilon = 0.1
# average reward in episode 268 = 2.0
#
#
# done at step 438
# episode 269/1000000
# number of seen frames = 8963116
# epsilon = 0.1
# average reward in episode 269 = 0.0
#
#
# done at step 208
# episode 270/1000000
# number of seen frames = 8963324
# epsilon = 0.1
# average reward in episode 270 = 0.0
#
#
# done at step 214
# episode 271/1000000
# number of seen frames = 8963538
# epsilon = 0.1
# average reward in episode 271 = 0.0
#
#
# done at step 347
# episode 272/1000000
# number of seen frames = 8963885
# epsilon = 0.09999910000000001
# average reward in episode 272 = 0.0
#
#
# done at step 301
# episode 273/1000000
# number of seen frames = 8964186
# epsilon = 0.1
# average reward in episode 273 = 0.0
#
#
# done at step 142
# episode 274/1000000
# number of seen frames = 8964328
# epsilon = 0.1
# average reward in episode 274 = 0.0
#
#
# done at step 270
# episode 275/1000000
# number of seen frames = 8964598
# epsilon = 0.1
# average reward in episode 275 = 0.0
#
#
# done at step 275
# episode 276/1000000
# number of seen frames = 8964873
# epsilon = 0.09999910000000001
# average reward in episode 276 = 0.0
#
#
# done at step 109
# episode 277/1000000
# number of seen frames = 8964982
# epsilon = 0.1
# average reward in episode 277 = 0.0
#
#
# done at step 224
# episode 278/1000000
# number of seen frames = 8965206
# epsilon = 0.1
# average reward in episode 278 = 0.0
#
#
# done at step 272
# episode 279/1000000
# number of seen frames = 8965478
# epsilon = 0.1
# average reward in episode 279 = 0.0
#
#
# done at step 321
# episode 280/1000000
# number of seen frames = 8965799
# epsilon = 0.09999910000000001
# average reward in episode 280 = 0.0
#
#
# done at step 185
# episode 281/1000000
# number of seen frames = 8965984
# epsilon = 0.1
# average reward in episode 281 = 0.0
#
#
# done at step 172
# episode 282/1000000
# number of seen frames = 8966156
# epsilon = 0.1
# average reward in episode 282 = 0.0
#
#
# done at step 143
# episode 283/1000000
# number of seen frames = 8966299
# epsilon = 0.09999910000000001
# average reward in episode 283 = 0.0
#
#
# done at step 162
# episode 284/1000000
# number of seen frames = 8966461
# epsilon = 0.09999910000000001
# average reward in episode 284 = 0.0
#
#
# done at step 325
# episode 285/1000000
# number of seen frames = 8966786
# epsilon = 0.1
# average reward in episode 285 = 0.0
#
#
# done at step 268
# episode 286/1000000
# number of seen frames = 8967054
# epsilon = 0.1
# average reward in episode 286 = 0.0
#
#
# done at step 144
# episode 287/1000000
# number of seen frames = 8967198
# epsilon = 0.1
# average reward in episode 287 = 0.0
#
#
# done at step 337
# episode 288/1000000
# number of seen frames = 8967535
# epsilon = 0.09999910000000001
# average reward in episode 288 = 1.0
#
#
# done at step 300
# episode 289/1000000
# number of seen frames = 8967835
# epsilon = 0.09999910000000001
# average reward in episode 289 = 2.0
#
#
# done at step 308
# episode 290/1000000
# number of seen frames = 8968143
# epsilon = 0.09999910000000001
# average reward in episode 290 = 0.0
#
#
# done at step 214
# episode 291/1000000
# number of seen frames = 8968357
# epsilon = 0.09999910000000001
# average reward in episode 291 = 0.0
#
#
# done at step 153
# episode 292/1000000
# number of seen frames = 8968510
# epsilon = 0.1
# average reward in episode 292 = 0.0
#
#
# done at step 236
# episode 293/1000000
# number of seen frames = 8968746
# epsilon = 0.1
# average reward in episode 293 = 0.0
#
#
# done at step 133
# episode 294/1000000
# number of seen frames = 8968879
# epsilon = 0.09999910000000001
# average reward in episode 294 = 1.0
#
#
# done at step 341
# episode 295/1000000
# number of seen frames = 8969220
# epsilon = 0.1
# average reward in episode 295 = 0.0
#
#
# done at step 195
# episode 296/1000000
# number of seen frames = 8969415
# epsilon = 0.09999910000000001
# average reward in episode 296 = 0.0
#
#
# done at step 160
# episode 297/1000000
# number of seen frames = 8969575
# epsilon = 0.09999910000000001
# average reward in episode 297 = 0.0
#
#
# done at step 252
# episode 298/1000000
# number of seen frames = 8969827
# epsilon = 0.09999910000000001
# average reward in episode 298 = 0.0
#
#
# done at step 194
# episode 299/1000000
# number of seen frames = 8970021
# epsilon = 0.09999910000000001
# average reward in episode 299 = 0.0
#
#
# done at step 279
# episode 300/1000000
# number of seen frames = 8970300
# epsilon = 0.1
# average reward in episode 300 = 0.0
#
#
# done at step 290
# episode 301/1000000
# number of seen frames = 8970590
# epsilon = 0.1
# average reward in episode 301 = 1.0
#
#
# done at step 209
# episode 302/1000000
# number of seen frames = 8970799
# epsilon = 0.09999910000000001
# average reward in episode 302 = 0.0
#
#
# done at step 218
# episode 303/1000000
# number of seen frames = 8971017
# epsilon = 0.09999910000000001
# average reward in episode 303 = 0.0
#
#
# done at step 381
# episode 304/1000000
# number of seen frames = 8971398
# epsilon = 0.1
# average reward in episode 304 = 0.0
#
#
# done at step 236
# episode 305/1000000
# number of seen frames = 8971634
# epsilon = 0.1
# average reward in episode 305 = 0.0
#
#
# done at step 197
# episode 306/1000000
# number of seen frames = 8971831
# epsilon = 0.09999910000000001
# average reward in episode 306 = 0.0
#
#
# done at step 276
# episode 307/1000000
# number of seen frames = 8972107
# epsilon = 0.09999910000000001
# average reward in episode 307 = 0.0
#
#
# done at step 256
# episode 308/1000000
# number of seen frames = 8972363
# epsilon = 0.09999910000000001
# average reward in episode 308 = 0.0
#
#
# done at step 379
# episode 309/1000000
# number of seen frames = 8972742
# epsilon = 0.1
# average reward in episode 309 = 0.0
#
#
# done at step 211
# episode 310/1000000
# number of seen frames = 8972953
# epsilon = 0.09999910000000001
# average reward in episode 310 = 0.0
#
#
# done at step 310
# episode 311/1000000
# number of seen frames = 8973263
# epsilon = 0.09999910000000001
# average reward in episode 311 = 0.0
#
#
# done at step 177
# episode 312/1000000
# number of seen frames = 8973440
# epsilon = 0.1
# average reward in episode 312 = 0.0
#
#
# done at step 264
# episode 313/1000000
# number of seen frames = 8973704
# epsilon = 0.1
# average reward in episode 313 = 0.0
#
#
# done at step 270
# episode 314/1000000
# number of seen frames = 8973974
# epsilon = 0.1
# average reward in episode 314 = 0.0
#
#
# done at step 291
# episode 315/1000000
# number of seen frames = 8974265
# epsilon = 0.09999910000000001
# average reward in episode 315 = 0.0
#
#
# done at step 280
# episode 316/1000000
# number of seen frames = 8974545
# epsilon = 0.09999910000000001
# average reward in episode 316 = 0.0
#
#
# done at step 205
# episode 317/1000000
# number of seen frames = 8974750
# epsilon = 0.1
# average reward in episode 317 = 0.0
#
#
# done at step 199
# episode 318/1000000
# number of seen frames = 8974949
# epsilon = 0.09999910000000001
# average reward in episode 318 = 0.0
#
#
# done at step 102
# episode 319/1000000
# number of seen frames = 8975051
# epsilon = 0.09999910000000001
# average reward in episode 319 = 0.0
#
#
# done at step 366
# episode 320/1000000
# number of seen frames = 8975417
# epsilon = 0.09999910000000001
# average reward in episode 320 = 1.0
#
#
# done at step 263
# episode 321/1000000
# number of seen frames = 8975680
# epsilon = 0.1
# average reward in episode 321 = 0.0
#
#
# done at step 189
# episode 322/1000000
# number of seen frames = 8975869
# epsilon = 0.09999910000000001
# average reward in episode 322 = 0.0
#
#
# done at step 231
# episode 323/1000000
# number of seen frames = 8976100
# epsilon = 0.1
# average reward in episode 323 = 0.0
#
#
# done at step 132
# episode 324/1000000
# number of seen frames = 8976232
# epsilon = 0.1
# average reward in episode 324 = 0.0
#
#
# done at step 176
# episode 325/1000000
# number of seen frames = 8976408
# epsilon = 0.1
# average reward in episode 325 = 0.0
#
#
# done at step 208
# episode 326/1000000
# number of seen frames = 8976616
# epsilon = 0.1
# average reward in episode 326 = 0.0
#
#
# done at step 266
# episode 327/1000000
# number of seen frames = 8976882
# epsilon = 0.1
# average reward in episode 327 = 0.0
#
#
# done at step 199
# episode 328/1000000
# number of seen frames = 8977081
# epsilon = 0.09999910000000001
# average reward in episode 328 = 0.0
#
#
# done at step 238
# episode 329/1000000
# number of seen frames = 8977319
# epsilon = 0.09999910000000001
# average reward in episode 329 = 0.0
#
#
# done at step 170
# episode 330/1000000
# number of seen frames = 8977489
# epsilon = 0.09999910000000001
# average reward in episode 330 = 0.0
#
#
# done at step 199
# episode 331/1000000
# number of seen frames = 8977688
# epsilon = 0.1
# average reward in episode 331 = 0.0
#
#
# done at step 304
# episode 332/1000000
# number of seen frames = 8977992
# epsilon = 0.1
# average reward in episode 332 = 0.0
#
#
# done at step 390
# episode 333/1000000
# number of seen frames = 8978382
# epsilon = 0.1
# average reward in episode 333 = 0.0
#
#
# done at step 307
# episode 334/1000000
# number of seen frames = 8978689
# epsilon = 0.09999910000000001
# average reward in episode 334 = 0.0
#
#
# ...
# epsilon = 0.09999910000000001
# average reward in episode 1336 = 0.0
#
#
# done at step 208
# episode 1337/1000000
# number of seen frames = 9233861
# epsilon = 0.09999910000000001
# average reward in episode 1337 = 0.0
#
#
# done at step 249
# episode 1338/1000000
# number of seen frames = 9234110
# epsilon = 0.1
# average reward in episode 1338 = 0.0
#
#
# done at step 206
# episode 1339/1000000
# number of seen frames = 9234316
# epsilon = 0.1
# average reward in episode 1339 = 0.0
#
#
# done at step 232
# episode 1340/1000000
# number of seen frames = 9234548
# epsilon = 0.1
# average reward in episode 1340 = 0.0
#
#
# done at step 271
# episode 1341/1000000
# number of seen frames = 9234819
# epsilon = 0.09999910000000001
# average reward in episode 1341 = 0.0
#
#
# done at step 185
# episode 1342/1000000
# number of seen frames = 9235004
# epsilon = 0.1
# average reward in episode 1342 = 0.0
#
#
# done at step 337
# episode 1343/1000000
# number of seen frames = 9235341
# epsilon = 0.09999910000000001
# average reward in episode 1343 = 0.0
#
#
# done at step 253
# episode 1344/1000000
# number of seen frames = 9235594
# epsilon = 0.1
# average reward in episode 1344 = 0.0
#
#
# done at step 260
# episode 1345/1000000
# number of seen frames = 9235854
# epsilon = 0.1
# average reward in episode 1345 = 0.0
#
#
# done at step 165
# episode 1346/1000000
# number of seen frames = 9236019
# epsilon = 0.09999910000000001
# average reward in episode 1346 = 0.0
#
#
# done at step 200
# episode 1347/1000000
# number of seen frames = 9236219
# epsilon = 0.09999910000000001
# average reward in episode 1347 = 0.0
#
#
# done at step 226
# episode 1348/1000000
# number of seen frames = 9236445
# epsilon = 0.09999910000000001
# average reward in episode 1348 = 0.0
#
#
# done at step 191
# episode 1349/1000000
# number of seen frames = 9236636
# epsilon = 0.1
# average reward in episode 1349 = 0.0
#
#
# done at step 96
# episode 1350/1000000
# number of seen frames = 9236732
# epsilon = 0.1
# average reward in episode 1350 = 0.0
#
#
# done at step 157
# episode 1351/1000000
# number of seen frames = 9236889
# epsilon = 0.09999910000000001
# average reward in episode 1351 = 1.0
#
#
# done at step 244
# episode 1352/1000000
# number of seen frames = 9237133
# epsilon = 0.09999910000000001
# average reward in episode 1352 = 0.0
#
#
# done at step 470
# episode 1353/1000000
# number of seen frames = 9237603
# epsilon = 0.09999910000000001
# average reward in episode 1353 = 2.0
#
#
# done at step 371
# episode 1354/1000000
# number of seen frames = 9237974
# epsilon = 0.1
# average reward in episode 1354 = 1.0
#
#
# done at step 327
# episode 1355/1000000
# number of seen frames = 9238301
# epsilon = 0.09999910000000001
# average reward in episode 1355 = 1.0
#
#
# done at step 329
# episode 1356/1000000
# number of seen frames = 9238630
# epsilon = 0.1
# average reward in episode 1356 = 0.0
#
#
# done at step 253
# episode 1357/1000000
# number of seen frames = 9238883
# epsilon = 0.09999910000000001
# average reward in episode 1357 = 2.0
#
#
# done at step 230
# episode 1358/1000000
# number of seen frames = 9239113
# epsilon = 0.09999910000000001
# average reward in episode 1358 = 0.0
#
#
# done at step 289
# episode 1359/1000000
# number of seen frames = 9239402
# epsilon = 0.1
# average reward in episode 1359 = 1.0
#
#
# done at step 153
# episode 1360/1000000
# number of seen frames = 9239555
# epsilon = 0.09999910000000001
# average reward in episode 1360 = 0.0
#
#
# done at step 239
# episode 1361/1000000
# number of seen frames = 9239794
# epsilon = 0.1
# average reward in episode 1361 = 1.0
#
#
# done at step 282
# episode 1362/1000000
# number of seen frames = 9240076
# epsilon = 0.1
# average reward in episode 1362 = 1.0
#
#
# done at step 225
# episode 1363/1000000
# number of seen frames = 9240301
# epsilon = 0.09999910000000001
# average reward in episode 1363 = 1.0
#
#
# done at step 306
# episode 1364/1000000
# number of seen frames = 9240607
# epsilon = 0.09999910000000001
# average reward in episode 1364 = 0.0
#
#
# done at step 423
# episode 1365/1000000
# number of seen frames = 9241030
# epsilon = 0.1
# average reward in episode 1365 = 0.0
#
#
# done at step 249
# episode 1366/1000000
# number of seen frames = 9241279
# epsilon = 0.09999910000000001
# average reward in episode 1366 = 0.0
#
#
# done at step 299
# episode 1367/1000000
# number of seen frames = 9241578
# epsilon = 0.1
# average reward in episode 1367 = 1.0
#
#
# done at step 282
# episode 1368/1000000
# number of seen frames = 9241860
# epsilon = 0.1
# average reward in episode 1368 = 0.0
#
#
# done at step 188
# episode 1369/1000000
# number of seen frames = 9242048
# epsilon = 0.1
# average reward in episode 1369 = 0.0
#
#
# done at step 137
# episode 1370/1000000
# number of seen frames = 9242185
# epsilon = 0.09999910000000001
# average reward in episode 1370 = 0.0
#
#
# done at step 231
# episode 1371/1000000
# number of seen frames = 9242416
# epsilon = 0.1
# average reward in episode 1371 = 1.0
#
#
# done at step 181
# episode 1372/1000000
# number of seen frames = 9242597
# epsilon = 0.09999910000000001
# average reward in episode 1372 = 0.0
#
#
# done at step 359
# episode 1373/1000000
# number of seen frames = 9242956
# epsilon = 0.1
# average reward in episode 1373 = 1.0
#
#
# done at step 289
# episode 1374/1000000
# number of seen frames = 9243245
# epsilon = 0.09999910000000001
# average reward in episode 1374 = 2.0
#
#
# done at step 252
# episode 1375/1000000
# number of seen frames = 9243497
# epsilon = 0.09999910000000001
# average reward in episode 1375 = 2.0
#
#
# done at step 332
# episode 1376/1000000
# number of seen frames = 9243829
# epsilon = 0.09999910000000001
# average reward in episode 1376 = 2.0
#
#
# done at step 211
# episode 1377/1000000
# number of seen frames = 9244040
# epsilon = 0.1
# average reward in episode 1377 = 0.0
#
#
# done at step 335
# episode 1378/1000000
# number of seen frames = 9244375
# epsilon = 0.09999910000000001
# average reward in episode 1378 = 0.0
#
#
# done at step 226
# episode 1379/1000000
# number of seen frames = 9244601
# epsilon = 0.09999910000000001
# average reward in episode 1379 = 0.0
#
#
# done at step 315
# episode 1380/1000000
# number of seen frames = 9244916
# epsilon = 0.1
# average reward in episode 1380 = 1.0
#
#
# done at step 185
# episode 1381/1000000
# number of seen frames = 9245101
# epsilon = 0.09999910000000001
# average reward in episode 1381 = 0.0
#
#
# done at step 231
# episode 1382/1000000
# number of seen frames = 9245332
# epsilon = 0.1
# average reward in episode 1382 = 0.0
#
#
# done at step 318
# episode 1383/1000000
# number of seen frames = 9245650
# epsilon = 0.1
# average reward in episode 1383 = 0.0
#
#
# done at step 259
# episode 1384/1000000
# number of seen frames = 9245909
# epsilon = 0.09999910000000001
# average reward in episode 1384 = 0.0
#
#
# done at step 335
# episode 1385/1000000
# number of seen frames = 9246244
# epsilon = 0.1
# average reward in episode 1385 = 1.0
#
#
# done at step 421
# episode 1386/1000000
# number of seen frames = 9246665
# epsilon = 0.09999910000000001
# average reward in episode 1386 = 5.0
#
#
# done at step 170
# episode 1387/1000000
# number of seen frames = 9246835
# epsilon = 0.09999910000000001
# average reward in episode 1387 = 0.0
#
#
# done at step 282
# episode 1388/1000000
# number of seen frames = 9247117
# epsilon = 0.09999910000000001
# average reward in episode 1388 = 0.0
#
#
# done at step 126
# episode 1389/1000000
# number of seen frames = 9247243
# epsilon = 0.09999910000000001
# average reward in episode 1389 = 0.0
#
#
# done at step 245
# episode 1390/1000000
# number of seen frames = 9247488
# epsilon = 0.1
# average reward in episode 1390 = 0.0
#
#
# done at step 258
# episode 1391/1000000
# number of seen frames = 9247746
# epsilon = 0.1
# average reward in episode 1391 = 0.0
#
#
# done at step 154
# episode 1392/1000000
# number of seen frames = 9247900
# epsilon = 0.1
# average reward in episode 1392 = 0.0
#
#
# done at step 221
# episode 1393/1000000
# number of seen frames = 9248121
# epsilon = 0.09999910000000001
# average reward in episode 1393 = 0.0
#
#
# done at step 191
# episode 1394/1000000
# number of seen frames = 9248312
# epsilon = 0.1
# average reward in episode 1394 = 0.0
#
#
# done at step 191
# episode 1395/1000000
# number of seen frames = 9248503
# epsilon = 0.09999910000000001
# average reward in episode 1395 = 0.0
#
#
# done at step 252
# episode 1396/1000000
# number of seen frames = 9248755
# epsilon = 0.09999910000000001
# average reward in episode 1396 = 0.0
#
#
# done at step 310
# episode 1397/1000000
# number of seen frames = 9249065
# epsilon = 0.09999910000000001
# average reward in episode 1397 = 0.0
#
#
# done at step 178
# episode 1398/1000000
# number of seen frames = 9249243
# epsilon = 0.09999910000000001
# average reward in episode 1398 = 0.0
#
#
# done at step 363
# episode 1399/1000000
# number of seen frames = 9249606
# epsilon = 0.1
# average reward in episode 1399 = 1.0
#
#
# done at step 293
# episode 1400/1000000
# number of seen frames = 9249899
# epsilon = 0.09999910000000001
# average reward in episode 1400 = 0.0
#
#
# done at step 220
# episode 1401/1000000
# number of seen frames = 9250119
# epsilon = 0.09999910000000001
# average reward in episode 1401 = 0.0
#
#
# done at step 187
# episode 1402/1000000
# number of seen frames = 9250306
# epsilon = 0.1
# average reward in episode 1402 = 0.0
#
#
# done at step 278
# episode 1403/1000000
# number of seen frames = 9250584
# epsilon = 0.1
# average reward in episode 1403 = 0.0
#
#
# done at step 198
# episode 1404/1000000
# number of seen frames = 9250782
# epsilon = 0.1
# average reward in episode 1404 = 0.0
#
#
# done at step 304
# episode 1405/1000000
# number of seen frames = 9251086
# epsilon = 0.1
# average reward in episode 1405 = 1.0
#
#
# done at step 224
# episode 1406/1000000
# number of seen frames = 9251310
# epsilon = 0.1
# average reward in episode 1406 = 0.0
#
#
# done at step 156
# episode 1407/1000000
# number of seen frames = 9251466
# epsilon = 0.1
# average reward in episode 1407 = 0.0
#
#
# done at step 146
# episode 1408/1000000
# number of seen frames = 9251612
# epsilon = 0.1
# average reward in episode 1408 = 0.0
#
#
# done at step 165
# episode 1409/1000000
# number of seen frames = 9251777
# epsilon = 0.09999910000000001
# average reward in episode 1409 = 0.0
#
#
# done at step 336
# episode 1410/1000000
# number of seen frames = 9252113
# epsilon = 0.09999910000000001
# average reward in episode 1410 = 3.0
#
#
# done at step 231
# episode 1411/1000000
# number of seen frames = 9252344
# epsilon = 0.1
# average reward in episode 1411 = 0.0
#
#
# done at step 345
# episode 1412/1000000
# number of seen frames = 9252689
# epsilon = 0.09999910000000001
# average reward in episode 1412 = 0.0
#
#
# done at step 140
# episode 1413/1000000
# number of seen frames = 9252829
# epsilon = 0.09999910000000001
# average reward in episode 1413 = 0.0
#
#
# done at step 136
# episode 1414/1000000
# number of seen frames = 9252965
# epsilon = 0.09999910000000001
# average reward in episode 1414 = 0.0
#
#
# done at step 198
# episode 1415/1000000
# number of seen frames = 9253163
# epsilon = 0.09999910000000001
# average reward in episode 1415 = 1.0
#
#
# done at step 220
# episode 1416/1000000
# number of seen frames = 9253383
# epsilon = 0.09999910000000001
# average reward in episode 1416 = 0.0
#
#
# done at step 419
# episode 1417/1000000
# number of seen frames = 9253802
# epsilon = 0.1
# average reward in episode 1417 = 0.0
#
#
# done at step 202
# episode 1418/1000000
# number of seen frames = 9254004
# epsilon = 0.1
# average reward in episode 1418 = 1.0
#
#
# done at step 403
# episode 1419/1000000
# number of seen frames = 9254407
# epsilon = 0.09999910000000001
# average reward in episode 1419 = 4.0
#
#
# done at step 202
# episode 1420/1000000
# number of seen frames = 9254609
# epsilon = 0.09999910000000001
# average reward in episode 1420 = 0.0
#
#
# done at step 250
# episode 1421/1000000
# number of seen frames = 9254859
# epsilon = 0.09999910000000001
# average reward in episode 1421 = 1.0
#
#
# done at step 200
# episode 1422/1000000
# number of seen frames = 9255059
# epsilon = 0.09999910000000001
# average reward in episode 1422 = 0.0
#
#
# done at step 304
# episode 1423/1000000
# number of seen frames = 9255363
# epsilon = 0.09999910000000001
# average reward in episode 1423 = 0.0
#
#
# done at step 324
# episode 1424/1000000
# number of seen frames = 9255687
# epsilon = 0.09999910000000001
# average reward in episode 1424 = 2.0
#
#
# done at step 276
# episode 1425/1000000
# number of seen frames = 9255963
# epsilon = 0.09999910000000001
# average reward in episode 1425 = 2.0
#
#
# done at step 219
# episode 1426/1000000
# number of seen frames = 9256182
# epsilon = 0.1
# average reward in episode 1426 = 0.0
#
#
# done at step 484
# episode 1427/1000000
# number of seen frames = 9256666
# epsilon = 0.1
# average reward in episode 1427 = 3.0
#
#
# done at step 226
# episode 1428/1000000
# number of seen frames = 9256892
# epsilon = 0.1
# average reward in episode 1428 = 0.0
#
#
# done at step 178
# episode 1429/1000000
# number of seen frames = 9257070
# epsilon = 0.1
# average reward in episode 1429 = 0.0
#
#
# done at step 323
# episode 1430/1000000
# number of seen frames = 9257393
# epsilon = 0.09999910000000001
# average reward in episode 1430 = 0.0
#
#
# done at step 217
# episode 1431/1000000
# number of seen frames = 9257610
# epsilon = 0.1
# average reward in episode 1431 = 1.0
#
#
# done at step 422
# episode 1432/1000000
# number of seen frames = 9258032
# epsilon = 0.1
# average reward in episode 1432 = 2.0
#
#
# done at step 231
# episode 1433/1000000
# number of seen frames = 9258263
# epsilon = 0.09999910000000001
# average reward in episode 1433 = 0.0
#
#
# done at step 165
# episode 1434/1000000
# number of seen frames = 9258428
# epsilon = 0.1
# average reward in episode 1434 = 0.0
#
#
# done at step 342
# episode 1435/1000000
# number of seen frames = 9258770
# epsilon = 0.1
# average reward in episode 1435 = 0.0
#
#
# done at step 308
# episode 1436/1000000
# number of seen frames = 9259078
# epsilon = 0.1
# average reward in episode 1436 = 0.0
#
#
# done at step 201
# episode 1437/1000000
# number of seen frames = 9259279
# epsilon = 0.09999910000000001
# average reward in episode 1437 = 0.0
#
#
# done at step 182
# episode 1438/1000000
# number of seen frames = 9259461
# epsilon = 0.09999910000000001
# average reward in episode 1438 = 0.0
#
#
# done at step 223
# episode 1439/1000000
# number of seen frames = 9259684
# epsilon = 0.1
# average reward in episode 1439 = 1.0
#
#
# done at step 288
# episode 1440/1000000
# number of seen frames = 9259972
# epsilon = 0.1
# average reward in episode 1440 = 0.0
#
#
# done at step 348
# episode 1441/1000000
# number of seen frames = 9260320
# epsilon = 0.1
# average reward in episode 1441 = 0.0
#
#
# done at step 458
# episode 1442/1000000
# number of seen frames = 9260778
# epsilon = 0.1
# average reward in episode 1442 = 2.0
#
#
# done at step 331
# episode 1443/1000000
# number of seen frames = 9261109
# epsilon = 0.09999910000000001
# average reward in episode 1443 = 1.0
#
#
# done at step 192
# episode 1444/1000000
# number of seen frames = 9261301
# epsilon = 0.09999910000000001
# average reward in episode 1444 = 0.0
#
#
# done at step 207
# episode 1445/1000000
# number of seen frames = 9261508
# epsilon = 0.1
# average reward in episode 1445 = 0.0
#
#
# done at step 249
# episode 1446/1000000
# number of seen frames = 9261757
# epsilon = 0.09999910000000001
# average reward in episode 1446 = 0.0
#
#
# done at step 275
# episode 1447/1000000
# number of seen frames = 9262032
# epsilon = 0.1
# average reward in episode 1447 = 0.0
#
#
# done at step 337
# episode 1448/1000000
# number of seen frames = 9262369
# epsilon = 0.09999910000000001
# average reward in episode 1448 = 0.0
#
#
# done at step 463
# episode 1449/1000000
# number of seen frames = 9262832
# epsilon = 0.1
# average reward in episode 1449 = 0.0
#
#
# done at step 299
# episode 1450/1000000
# number of seen frames = 9263131
# epsilon = 0.09999910000000001
# average reward in episode 1450 = 1.0
#
#
# done at step 320
# episode 1451/1000000
# number of seen frames = 9263451
# epsilon = 0.09999910000000001
# average reward in episode 1451 = 0.0
#
#
# done at step 290
# episode 1452/1000000
# number of seen frames = 9263741
# epsilon = 0.09999910000000001
# average reward in episode 1452 = 0.0
#
#
# done at step 268
# episode 1453/1000000
# number of seen frames = 9264009
# epsilon = 0.09999910000000001
# average reward in episode 1453 = 0.0
#
#
# done at step 222
# episode 1454/1000000
# number of seen frames = 9264231
# epsilon = 0.09999910000000001
# average reward in episode 1454 = 0.0
#
#
# done at step 227
# episode 1455/1000000
# number of seen frames = 9264458
# epsilon = 0.1
# average reward in episode 1455 = 0.0
#
#
# done at step 317
# episode 1456/1000000
# number of seen frames = 9264775
# epsilon = 0.09999910000000001
# average reward in episode 1456 = 0.0
#
#
# done at step 119
# episode 1457/1000000
# number of seen frames = 9264894
# epsilon = 0.1
# average reward in episode 1457 = 0.0
